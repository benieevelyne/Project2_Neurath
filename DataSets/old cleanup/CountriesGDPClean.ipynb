# %%
import pandas as pd
import numpy as np

# %%
# gdp = pandas.read_csv('gdp.csv')
Countries_GDP = pd.read_csv('CountriesGDP19902017.csv')

# %%
Countries_GDP.head()
# Out:
#                                      Series Name        Series Code  \
# 0  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 1  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 2  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 3  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 4  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
#
#      Country Name Country Code 1990 [YR1990] 1995 [YR1995] 2000 [YR2000]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB   2722.280344   2782.093734   4029.016971
# 2         Algeria          DZA   6616.408352   6777.297778   8093.530893
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2005 [YR2005] 2010 [YR2010] 2015 [YR2015] 2017 [YR2017]
# 0   1011.595524   1581.600836   1926.357336   1980.516177
# ...

# %%
Countries_GDP = Countries_GDP.drop(['Series Name','Series Code', 'Country Code'], axis=1)
Countries_GDP.head()
# Out:
#      Country Name 1990 [YR1990] 1995 [YR1995] 2000 [YR2000] 2005 [YR2005]  \
# 0     Afghanistan            ..            ..            ..   1011.595524
# 1         Albania   2722.280344   2782.093734   4029.016971   5942.884009
# 2         Algeria   6616.408352   6777.297778   8093.530893   10971.84687
# 3  American Samoa            ..            ..            ..            ..
# 4         Andorra            ..            ..            ..            ..
#
#   2010 [YR2010] 2015 [YR2015] 2017 [YR2017]
# 0   1581.600836   1926.357336   1980.516177
# 1   9637.345368   11334.22093   12020.69073
# 2   12610.24805   14614.97043   15275.37422
# 3            ..            ..            ..
# 4            ..            ..            ..

# %%
Countries_GDP.rename(columns={"1990 [YR1990]":"1990", "1995 [YR1995]":"1995", "2000 [YR2000]":"2000", "2005 [YR2005]":"2005", "2010 [YR2010]":"2010", "2015 [YR2015]":"2015", "2017 [YR2017]":"1995"})
# Out:
#                                           Country Name         1990  \
# 0                                          Afghanistan           ..
# 1                                              Albania  2722.280344
# 2                                              Algeria  6616.408352
# 3                                       American Samoa           ..
# 4                                              Andorra           ..
# 5                                               Angola   2217.43838
# 6                                  Antigua and Barbuda  10587.59341
# 7                                            Argentina  6990.554045
# 8                                              Armenia  2418.860926
# 9                                                Aruba           ..
# 10                                           Australia   17338.4672
# 11                                             Austria  19452.46636
# 12                                          Azerbaijan  5502.433989
# ...
