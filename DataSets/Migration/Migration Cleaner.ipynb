# %%
import pandas as pd
import numpy as np

# %%
# gdp = pandas.read_csv('gdp.csv')
migration = pd.read_csv('UN_MigrantStockTotal_2017 .csv', skiprows=15)

# %%
migration = pd.DataFrame(migration).reset_index(drop=True)
migration.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           1                                              WORLD        NaN
# 1           2                             More developed regions          b
# 2           3                             Less developed regions          c
# 3           4                          Least developed countries          d
# 4           5  Less developed regions, excluding least develo...        NaN
#
#    Unnamed: 3 Unnamed: 4       1990       1995       2000       2005  \
# 0         900        NaN  152542373  160700028  172604257  190531600
# 1         901        NaN   82391619   92331345  103417894  116295565
# 2         902        NaN   70150754   68368683   69186363   74236035
# 3         941        NaN   11073226   11708074   10073307    9803046
# 4         934        NaN   59116432   56701134   59155202   64483287
#
#         2010    ...         2010.1     2015.1     2017.1    1990.2    1995.2  \
# ...

# %%
migration = migration.iloc[13:]
migration.head()
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4     1990    1995  \
# 13          14    Burundi        NaN         108        B R   333110  254853
# 14          15    Comoros        NaN         174          B    14079   13939
# 15          16   Djibouti        NaN         262        B R   122221   99774
# 16          17    Eritrea        NaN         232          I    11848   12400
# 17          18   Ethiopia        NaN         231        B R  1155390  806904
#
#       2000    2005    2010   ...    2010.1  2015.1  2017.1  1990.2  1995.2  \
# 13  125628  172874  235259   ...    115823  142790  147599  169843  130688
# 14   13799   13209   12618   ...      6060    6071    6071    7362    7325
# 15  100507   92091  101575   ...     53295   59081   61025   57979   47298
# 16   12952   14314   15676   ...      8603    8833    8889    5620    5858
# 17  611384  514242  567720   ...    297534  591876  624222  548106  382787
#
#     2000.2  2005.2  2010.2  2015.2  2017.2
# ...

# %%
migration = migration.drop(['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)
migration.head()
# Out:
#    Unnamed: 1     1990    1995    2000    2005    2010     2015     2017  \
# 13    Burundi   333110  254853  125628  172874  235259   289810   299569
# 14    Comoros    14079   13939   13799   13209   12618    12555    12555
# 15   Djibouti   122221   99774  100507   92091  101575   112351   116089
# 16    Eritrea    11848   12400   12952   14314   15676    15941    16041
# 17   Ethiopia  1155390  806904  611384  514242  567720  1162576  1227143
#
#     1990.1  1995.1   ...    2010.1  2015.1  2017.1  1990.2  1995.2  2000.2  \
# 13  163267  124165   ...    115823  142790  147599  169843  130688   64534
# 14    6717    6614   ...      6060    6071    6071    7362    7325    7288
# 15   64242   52476   ...     53295   59081   61025   57979   47298   47587
# 16    6228    6542   ...      8603    8833    8889    5620    5858    6096
# 17  607284  424117   ...    297534  591876  624222  548106  382787  289165
#
#     2005.2  2010.2  2015.2  2017.2
# 13   88069  119436  147020  151970
# ...

# %%
migration
# Out:
#                            Unnamed: 1      1990      1995      2000      2005  \
# 13                            Burundi    333110    254853    125628    172874
# 14                            Comoros     14079     13939     13799     13209
# 15                           Djibouti    122221     99774    100507     92091
# 16                            Eritrea     11848     12400     12952     14314
# 17                           Ethiopia   1155390    806904    611384    514242
# 18                              Kenya    297292    618745    699139    756894
# 19                         Madagascar     23917     21177     23541     26058
# 20                             Malawi   1127724    241624    232620    221661
# 21                          Mauritius      3613      7493     15543     19647
# 22                            Mayotte     15229     26316     45474     63176
# 23                         Mozambique    122332    168256    195702    204830
# ...

# %%
migration.columns = ['country','1990total','1995total','2000total','2005total','2010total','2015total','2017total',
                      '1990male','1995male','2000male','2005male','2010male','2015male','2017male',
                      '1990female','1995female','2000female','2005female','2010female','2015female','2017female']

# %%
migration.head()
# Out:
#      country 1990total 1995total 2000total 2005total  2010total  2015total  \
# 13   Burundi    333110    254853    125628    172874     235259     289810
# 14   Comoros     14079     13939     13799     13209      12618      12555
# 15  Djibouti    122221     99774    100507     92091     101575     112351
# 16   Eritrea     11848     12400     12952     14314      15676      15941
# 17  Ethiopia   1155390    806904    611384    514242     567720    1162576
#
#     2017total 1990male 1995male     ...     2010male 2015male  2017male  \
# 13     299569   163267   124165     ...       115823   142790    147599
# 14      12555     6717     6614     ...         6060     6071      6071
# 15     116089    64242    52476     ...        53295    59081     61025
# 16      16041     6228     6542     ...         8603     8833      8889
# 17    1227143   607284   424117     ...       297534   591876    624222
#
#     1990female  1995female 2000female 2005female 2010female 2015female  \
# ...

# %%
migration.to_csv('CleanMigration.csv')

# %%
# trafficking = pd.read_csv('UN_MigrantStockTotal(clean).csv', skiprows=0)
# trafficking.head()
