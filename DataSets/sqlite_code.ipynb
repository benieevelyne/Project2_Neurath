# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df_gdp = pd.read_csv("Countries_GDP.csv",index_col=0)
df_gdp.head()
# Out:
#              Code  Year          GDP
# Country Name
# Afghanistan    AF  1990           ..
# Afghanistan    AF  1995           ..
# Afghanistan    AF  2000           ..
# Afghanistan    AF  2005  1011.595524
# Afghanistan    AF  2010  1581.600836

# %%
df_mig = pd.read_csv("MigrationCountsAge-Gender.csv", index_col=0)
df_mig.head()
# Out:
#                                                     Year    Total  TotalYouth  \
# Major area, region, country or area of destination
# Burundi                                             1990   333110       86938
# Comoros                                             1990    14079        3656
# Djibouti                                            1990   122221       41767
# Eritrea                                             1990    11848        3311
# Ethiopia                                            1990  1155390      396648
#
#                                                     TotalAdult  TotalElder  \
# Major area, region, country or area of destination
# Burundi                                                 230870       15302
# Comoros                                                   9973         450
# Djibouti                                                 77766        2688
# Eritrea                                                   8197         340
# ...

# %%
df_mig_year = pd.read_csv("NumberofPeopleMigrated_PerCountries_PerYear.csv", index_col=0)
df_mig_year.head()
# Out:
#    Years                           Countries of Destination            2  \
# 0   1990                                              WORLD  Afghanistan
# 1   1990                             More developed regions  Afghanistan
# 2   1990                             Less developed regions  Afghanistan
# 3   1990                          Least developed countries  Afghanistan
# 4   1990  Less developed regions, excluding least develo...  Afghanistan
#
#        value
# 0  6,724,681
# 1    119,338
# 2  6,605,343
# 3         ..
# 4  6,605,343

# %%
df_trafficking_counts = pd.read_csv("TraffickingCountsAge-Gender.csv", index_col=0)
df_mig_year.head()
# Out:
#    Years                           Countries of Destination            2  \
# 0   1990                                              WORLD  Afghanistan
# 1   1990                             More developed regions  Afghanistan
# 2   1990                             Less developed regions  Afghanistan
# 3   1990                          Least developed countries  Afghanistan
# 4   1990  Less developed regions, excluding least develo...  Afghanistan
#
#        value
# 0  6,724,681
# 1    119,338
# 2  6,605,343
# 3         ..
# 4  6,605,343

# %%
engine = create_engine("sqlite:///../db.sqlite")

# %%
df.to_sql("TraffickingCountsAge-Gender.csv",engine)

# %%
df.to_sql("NumberofPeopleMigrated_PerCountries_PerYear.csv.csv", engine)

# %%
query = "select * from Countries_GDP"
