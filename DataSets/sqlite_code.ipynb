# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df_gdp = pd.read_csv("Countries_GDP_Cleaned.csv",index_col=0)
df_gdp.head()
# Out:
#              Country Code  Years  GPD Values
# Country Name
# Afghanistan            AF   1990         0.0
# Afghanistan            AF   1991         0.0
# Afghanistan            AF   1992         0.0
# Afghanistan            AF   1993         0.0
# Afghanistan            AF   1994         0.0

# %%
df_mig = pd.read_csv("MigrationCountsAge-Gender.csv", index_col=0)
df_mig.head()
# Out:
#                                                     Year    Total  TotalYouth  \
# Major area, region, country or area of destination
# Burundi                                             1990   333110       86938
# Comoros                                             1990    14079        3656
# Djibouti                                            1990   122221       41767
# Eritrea                                             1990    11848        3311
# Ethiopia                                            1990  1155390      396648
#
#                                                     TotalAdult  TotalElder  \
# Major area, region, country or area of destination
# Burundi                                                 230870       15302
# Comoros                                                   9973         450
# Djibouti                                                 77766        2688
# Eritrea                                                   8197         340
# ...

# %%
df_mig_year = pd.read_csv("NumberPeopleMigratedFinal.csv", index_col=0)
df_mig_year.head()
# Out:
#               Years Countries of Origin  \
# Country Code
# AF             1990         Afghanistan
# AF             1990         Afghanistan
# AF             1990         Afghanistan
# AF             1990         Afghanistan
# AF             1990         Afghanistan
#
#                                        Countries of Destination  Total Count
# Country Code
# AF                                                        WORLD      6724681
# AF                                       More developed regions       119338
# AF                                       Less developed regions      6605343
# AF            Less developed regions, excluding least develo...      6605343
# AF                                        High-income countries       269865

# %%
df_trafficking_counts = pd.read_csv("TraffickingCountsAge-Gender.csv", index_col=0)
df_trafficking_counts.head()
# Out:
#              Year CountryOfExploitation  gender ageBroad  Count
# citizenship
# CO           2002               Unknown  Female    Adult     32
# CO           2002               Unknown  Female   Adult-     11
# CO           2002               Unknown  Female  Unknown     31
# MD           2002               Unknown  Female    Adult    396
# MD           2002               Unknown  Female   Adult-    132

# %%
engine = create_engine("sqlite:///../db.sqlite")

# %%
df_trafficking_counts.to_sql("TraffickingCountsAge-Gender.csv",engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2c6a350f44df> in <module>()
# ----> 1 df_trafficking_counts.to_sql("TraffickingCountsAge-Gender.csv",engine)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
df_mig_year.to_sql("NumberPeopleMigratedFinal.csv", engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-681438a3e7c1> in <module>()
# ----> 1 df_mig_year.to_sql("NumberPeopleMigratedFinal.csv", engine)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
df_mig.to_sql("MigrationCountsAge-Gender.csv", engine)

# %%
df_gdp.to_sql("Countries_GDP_Cleaned.csv", engine)

# %%
query = "select * from Countries_GDP"
