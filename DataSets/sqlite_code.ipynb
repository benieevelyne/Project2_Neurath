# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df_gdp = pd.read_csv("Countries_GDP_Cleaned.csv",index_col=0)
df_gdp.dtypes
# Out:
# Country Code     object
# Years             int64
# GPD Values      float64
# dtype: object

# %%
df_mig_age_gen = pd.read_csv("MigrationCountsAge_Gender_Final.csv", index_col=0)
df_mig_age_gen.head()
# Out:
#              Major area, region, country or area of destination  Year  \
# Country Code
# BI                                                      Burundi  1990
# KM                                                      Comoros  1990
# DJ                                                     Djibouti  1990
# ER                                                      Eritrea  1990
# ET                                                     Ethiopia  1990
#
#                 Total  TotalYouth  TotalAdult  TotalElder  TotalMale  \
# Country Code
# BI             333110       86938      230870       15302     163267
# KM              14079        3656        9973         450       6717
# DJ             122221       41767       77766        2688      64242
# ER              11848        3311        8197         340       6228
# ET            1155390      396648      711765       46977     607284
#
#               MaleYouth  MaleAdult  MaleElder  TotalFemale  FemaleYouth  \
# Country Code
# ...

# %%
df_mig_age_gen = df_mig_age_gen.rename(columns={"Major area, region, country or area of destination": "Destination"})

# %%
df_mig_age_gen.head()
# Out:
#              Destination  Year    Total  TotalYouth  TotalAdult  TotalElder  \
# Country Code
# BI               Burundi  1990   333110       86938      230870       15302
# KM               Comoros  1990    14079        3656        9973         450
# DJ              Djibouti  1990   122221       41767       77766        2688
# ER               Eritrea  1990    11848        3311        8197         340
# ET              Ethiopia  1990  1155390      396648      711765       46977
#
#               TotalMale  MaleYouth  MaleAdult  MaleElder  TotalFemale  \
# Country Code
# BI               163267      41491     114075       7701       169843
# KM                 6717       1561       4925        231         7362
# DJ                64242      22913      39825       1504        57979
# ER                 6228       1769       4305        154         5620
# ET               607284     211289     373118      22877       548106
#
#               FemaleYouth  FemaleAdult  FemaleElder
# ...

# %%
df_mig_age_gen.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-0345747766f7> in <module>()
# ----> 1 df_mig_age_gen.astype(int)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
# ...

# %%
df_mig_year = pd.read_csv("NumberPeopleMigratedFinal.csv", index_col=0)
df_mig_year.dtypes
# Out:
# Years                        int64
# Countries of Origin         object
# Countries of Destination    object
# Total Count                  int64
# dtype: object

# %%
df_trafficking_counts = pd.read_csv("TraffickingCountsAge-Gender.csv", index_col=0)
df_trafficking_counts.dtypes
# Out:
# Year                      int64
# CountryOfExploitation    object
# gender                   object
# ageBroad                 object
# Count                     int64
# dtype: object

# %%
# %pwd
# Out:
# '/Users/davidtabaka/Desktop/Project2_Neurath/DataSets'

# %%
engine = create_engine("sqlite:///db.sqlite")

# %%
df_trafficking_counts.to_sql("trafficking_counts",engine)

# %%
df_mig_year.to_sql("df_mig_year", engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-886df14da191> in <module>()
# ----> 1 df_mig_year.to_sql("df_mig_year", engine)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
df_mig_age_gen.to_sql("mig_age_gen", engine)

# %%
df_mig_age_gen.to_json(orient='records')
# Out:
# '[{"Year":1990,"Total":333110,"TotalYouth":86938,"TotalAdult":230870,"TotalElder":15302,"TotalMale":163267,"MaleYouth":41491,"MaleAdult":114075,"MaleElder":7701,"TotalFemale":169843,"FemaleYouth":45447,"FemaleAdult":116795,"FemaleElder":7601},{"Year":1990,"Total":14079,"TotalYouth":3656,"TotalAdult":9973,"TotalElder":450,"TotalMale":6717,"MaleYouth":1561,"MaleAdult":4925,"MaleElder":231,"TotalFemale":7362,"FemaleYouth":2095,"FemaleAdult":5048,"FemaleElder":219},{"Year":1990,"Total":122221,"TotalYouth":41767,"TotalAdult":77766,"TotalElder":2688,"TotalMale":64242,"MaleYouth":22913,"MaleAdult":39825,"MaleElder":1504,"TotalFemale":57979,"FemaleYouth":18854,"FemaleAdult":37941,"FemaleElder":1184},{"Year":1990,"Total":11848,"TotalYouth":3311,"TotalAdult":8197,"TotalElder":340,"TotalMale":6228,"MaleYouth":1769,"MaleAdult":4305,"MaleElder":154,"TotalFemale":5620,"FemaleYouth":1542,"FemaleAdult":3892,"FemaleElder":186},{"Year":1990,"Total":1155390,"TotalYouth":396648,"TotalAdult":711765,"Tota
# ...

# %%
df_gdp.to_sql("gdp", engine)

# %%
query = "select * from gdp"
df_gdp = pd.read_sql(query, engine)
df_gdp.head()
# Out:
#   Country Name Country Code  Years  GPD Values
# 0  Afghanistan           AF   1990         0.0
# 1  Afghanistan           AF   1991         0.0
# 2  Afghanistan           AF   1992         0.0
# 3  Afghanistan           AF   1993         0.0
# 4  Afghanistan           AF   1994         0.0

# %%
df_gdp.to_json(orient='records')
# Out:
# '[{"Country Code":"AF","Years":1990,"GPD Values":0.0},{"Country Code":"AF","Years":1991,"GPD Values":0.0},{"Country Code":"AF","Years":1992,"GPD Values":0.0},{"Country Code":"AF","Years":1993,"GPD Values":0.0},{"Country Code":"AF","Years":1994,"GPD Values":0.0},{"Country Code":"AF","Years":1995,"GPD Values":0.0},{"Country Code":"AF","Years":1996,"GPD Values":0.0},{"Country Code":"AF","Years":1997,"GPD Values":0.0},{"Country Code":"AF","Years":1998,"GPD Values":0.0},{"Country Code":"AF","Years":1999,"GPD Values":0.0},{"Country Code":"AF","Years":2000,"GPD Values":0.0},{"Country Code":"AF","Years":2001,"GPD Values":0.0},{"Country Code":"AF","Years":2002,"GPD Values":19243809663.0},{"Country Code":"AF","Years":2003,"GPD Values":21284923743.0},{"Country Code":"AF","Years":2004,"GPD Values":22101051955.0},{"Country Code":"AF","Years":2005,"GPD Values":25361507050.0},{"Country Code":"AF","Years":2006,"GPD Values":27592569519.0},{"Country Code":"AF","Years":2007,"GPD Values":32219074825.0},
# ...

# %%
query = "select * from trafficking_counts"
df_trafficking_counts = pd.read_sql(query, engine)
df_trafficking_counts.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a55c05d42c16> in <module>()
#       1 query = "select * from trafficking_counts"
# ----> 2 df_trafficking_counts = pd.read_sql(query, engine)
#       3 df_trafficking_counts.dtypes
#
# NameError: name 'engine' is not defined

# %%
df_trafficking_counts.to_json(orient='records')
# Out:
# '[{"Year":2002,"CountryOfExploitation":"Unknown","gender":"Female","ageBroad":"Adult","Count":32},{"Year":2002,"CountryOfExploitation":"Unknown","gender":"Female","ageBroad":"Adult-","Count":11},{"Year":2002,"CountryOfExploitation":"Unknown","gender":"Female","ageBroad":"Unknown","Count":31},{"Year":2002,"CountryOfExploitation":"Unknown","gender":"Female","ageBroad":"Adult","Count":396},{"Year":2002,"CountryOfExploitation":"Unknown","gender":"Female","ageBroad":"Adult-","Count":132},{"Year":2002,"CountryOfExploitation":"Y1","gender":"Female","ageBroad":"Adult","Count":129},{"Year":2002,"CountryOfExploitation":"Y1","gender":"Female","ageBroad":"Adult-","Count":27},{"Year":2002,"CountryOfExploitation":"BA","gender":"Female","ageBroad":"Adult","Count":19},{"Year":2002,"CountryOfExploitation":"BA","gender":"Female","ageBroad":"Adult-","Count":22},{"Year":2002,"CountryOfExploitation":"MK","gender":"Female","ageBroad":"Adult","Count":50},{"Year":2002,"CountryOfExploitation":"MK","gender":"
# ...

# %%
df_mig_year.to_json(o)
# Out:
#   Country Name Country Code  Years  GPD Values
# 0  Afghanistan           AF   1990         0.0
# 1  Afghanistan           AF   1991         0.0
# 2  Afghanistan           AF   1992         0.0
# 3  Afghanistan           AF   1993         0.0
# 4  Afghanistan           AF   1994         0.0

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://traffickAdmin:y2U3gQBgiV8Kq2u@traffickcluster-shard-00-00-xeuqd.mongodb.net:27017,traffickcluster-shard-00-01-xeuqd.mongodb.net:27017,traffickcluster-shard-00-02-xeuqd.mongodb.net:27017/test?ssl=true&replicaSet=TraffickCluster-shard-0&authSource=admin&retryWrites=true")

# %%
db = client.Neurath
Trafficking_Counts = db.trafficking_counts
Trafficking_Counts.insert_many(df_trafficking_counts.to_dict(orient='records'))

# %%
GDP = db.GDP
GDP.insert_many(df_gdp.to_dict(orient='records'))

# %%
Migration_Counts = db.Migration_Counts
Migration_Counts.insert_many(df_mig_age_gen.astype(str).to_dict(orient='records'))

# %%
Migration_Year = db.Migration_Year
Migration_Year.insert_many(df_mig_year.to_dict(orient='records'))
