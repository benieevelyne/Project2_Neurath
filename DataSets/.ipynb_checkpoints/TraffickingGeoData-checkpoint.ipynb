# %%
import pprint
import pandas
import geopandas
from pandas.io.json import json_normalize
import geojson

import json
import numpy
import math

# %%
with open('globe.geo.json') as f:
    data = geojson.load(f)
nestedglobe = pandas.DataFrame(data)
# globe['features'][1]
nestedglobe['features'][0]
# Out:
# {"geometry": {"coordinates": [[[-79.98928788999987, 15.794948635000056], [-79.9878230459999, 15.796210028000074], [-79.98639889199991, 15.794419664000086], [-79.98814856699991, 15.79417552300012], [-79.98928788999987, 15.794948635000056]]], "type": "Polygon"}, "properties": {"abbrev": null, "abbrev_len": 0, "adm0_a3": "BJN", "adm0_a3_is": "-99", "adm0_a3_un": -99, "adm0_a3_us": "B41", "adm0_a3_wb": -99, "adm0_dif": 0, "admin": "Bajo Nuevo Bank (Petrel Is.)", "brk_a3": "B41", "brk_diff": 1, "brk_group": null, "brk_name": "Bajo Nuevo Bank (Petrel Is.)", "continent": "North America", "economy": "7. Least developed region", "featurecla": "Admin-0 country", "filename": "bajonuevobankpetrelis.geojson", "fips_10_": "-99", "formal_en": null, "formal_fr": null, "gdp_md_est": -99, "gdp_year": 2012, "geou_dif": 0, "geounit": "Bajo Nuevo Bank (Petrel Is.)", "gu_a3": "BJN", "homepart": 1, "income_grp": "5. Low income", "iso_a2": "-99", "iso_a3": "-99", "iso_n3": "-99", "labelrank": 8, "lastcensus": -99, "level": 2, "long_len": 32, "mapcolor13": -99, "mapcolor7": 3, "mapcolor8": 7, "mapcolor9": 6, "name": "Bajo Nuevo Bank (Petrel Is.)", "name_alt": null, "name_len": 28, "name_long": "Bajo Nuevo Bank (Petrel Islands)", "name_sort": "Bajo Nuevo Bank (Petrel Is.)", "note_adm0": "Disputed", "note_brk": "Claimed by Columbia, Jamaica, Nicaragua and the United States", "pop_est": -99, "pop_year": 2012, "postal": null, "region_un": "Americas", "region_wb": "Latin America & Caribbean", "scalerank": 6, "sov_a3": "BJN", "sovereignt": "Bajo Nuevo Bank (Petrel Is.)", "su_a3": "BJN", "su_dif": 0, "subregion": "Caribbean", "subunit": "Bajo Nuevo Bank (Petrel Is.)", "tiny": -99, "type": "Indeterminate", "un_a3": "-099", "wb_a2": "-99", "wb_a3": "-99", "wikipedia": -99, "woe_id": -99, "woe_id_eh": -99, "woe_note": "No WOE equivalent."}, "type": "Feature"}

# %%
globe = pandas.io.json.json_normalize(nestedglobe['features'])
globe = globe.drop(['properties.abbrev', 'properties.abbrev_len',
              'properties.adm0_a3', 'properties.adm0_a3_is', 'properties.adm0_a3_un',
            'properties.adm0_a3_wb', 'properties.adm0_dif', 'properties.brk_diff',
             'properties.adm0_a3_us', 'properties.brk_a3', 'properties.brk_group',
             'properties.brk_name', 'properties.featurecla', 'properties.tiny',
             'properties.filename', 'properties.fips_10_', 'properties.formal_en',
             'properties.formal_fr', 'properties.gdp_md_est', 'properties.gdp_year',
             'properties.geounit', 'properties.subunit', 'properties.geou_dif', 
             'properties.gu_a3', 'properties.homepart', 'properties.iso_a3', 
              'properties.un_a3', 'properties.wb_a2', 'properties.wb_a3',
             'properties.wikipedia', 'properties.labelrank', 'properties.lastcensus',
             'properties.level', 'properties.sov_a3', 'properties.su_a3',
             'properties.su_dif', 'properties.subregion', 'properties.woe_id', 
             'properties.woe_note', 'properties.woe_id_eh', 'properties.long_len',
             'properties.mapcolor13','properties.mapcolor9','properties.mapcolor8',
             'properties.mapcolor7', 'properties.admin', 'properties.name_alt', 'properties.note_brk',
             'properties.postal', 'properties.pop_est', 'properties.pop_year', 
             'properties.note_brk', 'properties.region_un', 'properties.scalerank',
             'properties.iso_n3', 'properties.name_long', 'properties.name_sort',
             'properties.name_len', 'properties.region_wb', 'properties.note_adm0',
            'properties.continent', 'type'
             ], axis=1)
# df = df.set_index('properties.admin', drop=True)
globe.rename(columns = {'properties.iso_a2': 'properties.code'}, inplace=True)
globe['properties.code'] = globe['properties.code'].astype(str)
globe.sort_values('properties.code').head(250)
# Out:
#                                   geometry.coordinates geometry.type  \
# 0    [[[-79.98928788999987, 15.794948635000056], [-...       Polygon
# 41   [[[123.59701582100011, -12.428317966999899], [...       Polygon
# 42   [[[154.3912866550001, -21.030043226999865], [1...       Polygon
# 87   [[[[55.5013126960001, -20.87322356599999], [55...  MultiPolygon
# 94   [[[20.864700154000047, 43.217337342000036], [2...       Polygon
# 26   [[[-78.63707434799987, 15.862087307000108], [-...       Polygon
# 111  [[[[3.382578972000089, -54.44931405999998], [3...  MultiPolygon
# 160  [[[48.939111999908164, 11.249129976335054], [4...       Polygon
# 180  [[[33.905867961000126, 35.09088246600004], [33...       Polygon
# 182  [[[[32.626204468000225, 35.165089824000134], [...  MultiPolygon
# 183  [[[[33.92540165200015, 35.06277048700004], [33...  MultiPolygon
# 40   [[[[-75.18395510799986, 19.93359416400007], [-...  MultiPolygon
# 192  [[[63.3839136150001, 45.56582448300014], [63.3...       Polygon
# 187  [[[[96.9139103520001, -12.194512627999854], [9...  MultiPolygon
# 218  [[[117.753887178, 15.154369263000063], [117.75...       Polygon
# 228  [[[32.84080876400009, 34.69946744100013], [32....       Polygon
# 206  [[[[114.37647545700004, 9.68012116100013], [11...  MultiPolygon
# 195  [[[76.97641727700011, 35.57865631200005], [77....       Polygon
# 68   [[[1.707006470000067, 42.5027814740001], [1.69...       Polygon
# 178  [[[[53.863047722, 24.234686591000138], [53.888...  MultiPolygon
# 172  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 7    [[[[-61.773019985999916, 17.126532294000143], ...  MultiPolygon
# 1    [[[[-63.037668423999946, 18.212958075000028], ...  MultiPolygon
# 69   [[[19.747765747000074, 42.57890085900007], [19...       Polygon
# 174  [[[[45.54717289200002, 40.62155263300009], [45...  MultiPolygon
# 116  [[[[11.73751945100014, -16.692577982999833], [...  MultiPolygon
# 232  [[[[-68.65412350199998, -54.88624439899996], [...  MultiPolygon
# 39   [[[[-168.16047115799995, -14.520928643999968],...  MultiPolygon
# 71   [[[15.161792440000113, 48.93722076400007], [15...       Polygon
# 55   [[[[158.86573326900012, -54.749932549999826], ...  MultiPolygon
# ..                                                 ...           ...
# 222  [[[[99.247813347, 6.57485586100016], [99.26026...  MultiPolygon
# 220  [[[[70.61990604700006, 39.85069529200014], [70...  MultiPolygon
# 221  [[[[124.35455896000016, -9.364181823999871], [...  MultiPolygon
# 224  [[[[53.10206139400006, 38.755072333], [53.0947...  MultiPolygon
# 165  [[[[10.929942254000082, 33.896307684000035], [...  MultiPolygon
# 61   [[[[-176.20702063699989, -22.33879973799992], ...  MultiPolygon
# 227  [[[[26.04004967500012, 39.84503815300015], [26...  MultiPolygon
# 34   [[[[-60.90729732999998, 10.837144273000163], [...  MultiPolygon
# 60   [[[[179.90609785200013, -9.418633721999868], [...  MultiPolygon
# 225  [[[[121.58765709700006, 22.013861395], [121.56...  MultiPolygon
# 168  [[[[39.74916454600012, -8.065492432999873], [3...  MultiPolygon
# 113  [[[[29.807465040000153, 45.614325262000094], [...  MultiPolygon
# 166  [[[34.10802616400014, 3.868938091000103], [34....       Polygon
# 36   [[[[-160.0124405589999, -0.382094007999925], [...  MultiPolygon
# 57   [[[[-155.6065189699999, 20.137955566000144], [...  MultiPolygon
# 240  [[[-56.90636673999998, -30.108548685999907], [...       Polygon
# 226  [[[[71.75730432100013, 39.9030951940001], [71....  MultiPolygon
# 115  [[[12.45313691700008, 41.902751941000105], [12...       Polygon
# 37   [[[[-61.43272864499988, 12.587836005000113], [...  MultiPolygon
# 243  [[[[-61.39027141599987, 8.580580853000143], [-...  MultiPolygon
# 38   [[[[-64.56786048099994, 18.337388414000046], [...  MultiPolygon
# 43   [[[[-64.73078365799995, 17.765285549000126], [...  MultiPolygon
# 231  [[[[106.66871178500006, 8.753485419000171], [1...  MultiPolygon
# 62   [[[[169.83814537900005, -20.248630466999856], ...  MultiPolygon
# 65   [[[[-178.0467423169999, -14.312595309999978], ...  MultiPolygon
# 66   [[[[-171.5700170559999, -13.938164971999923], ...  MultiPolygon
# 229  [[[[53.308239457000155, 12.11839453700017], [5...  MultiPolygon
# 170  [[[[37.86378014400023, -46.94085051899984], [3...  MultiPolygon
# 169  [[[31.11983646700014, -8.616630553999912], [31...       Polygon
# 171  [[[30.010653524000077, -15.64622731499989], [3...       Polygon
#
#              properties.economy    properties.income_grp properties.code  \
# 0     7. Least developed region            5. Low income             -99
# 41    7. Least developed region            5. Low income             -99
# 42    7. Least developed region            5. Low income             -99
# 87      1. Developed region: G7     1. High income: OECD             -99
# 94         6. Developing region   4. Lower middle income             -99
# 26    7. Least developed region            5. Low income             -99
# 111  2. Developed region: nonG7     1. High income: OECD             -99
# 160        6. Developing region   4. Lower middle income             -99
# 180  2. Developed region: nonG7  2. High income: nonOECD             -99
# 182        6. Developing region   3. Upper middle income             -99
# 183        6. Developing region  2. High income: nonOECD             -99
# 40   2. Developed region: nonG7  2. High income: nonOECD             -99
# 192  2. Developed region: nonG7   3. Upper middle income             -99
# 187  2. Developed region: nonG7  2. High income: nonOECD             -99
# 218   7. Least developed region            5. Low income             -99
# 228  2. Developed region: nonG7  2. High income: nonOECD             -99
# 206   7. Least developed region            5. Low income             -99
# 195        6. Developing region   4. Lower middle income             -99
# 68   2. Developed region: nonG7  2. High income: nonOECD              AD
# 178        6. Developing region  2. High income: nonOECD              AE
# 172   7. Least developed region            5. Low income              AF
# 7          6. Developing region   3. Upper middle income              AG
# 1          6. Developing region   3. Upper middle income              AI
# 69         6. Developing region   4. Lower middle income              AL
# 174        6. Developing region   4. Lower middle income              AM
# 116   7. Least developed region   3. Upper middle income              AO
# 232     5. Emerging region: G20   3. Upper middle income              AR
# 39         6. Developing region   3. Upper middle income              AS
# 71   2. Developed region: nonG7     1. High income: OECD              AT
# 55   2. Developed region: nonG7     1. High income: OECD              AU
# ..                          ...                      ...             ...
# 222     5. Emerging region: G20   3. Upper middle income              TH
# 220        6. Developing region            5. Low income              TJ
# 221   7. Least developed region   4. Lower middle income              TL
# 224        6. Developing region   3. Upper middle income              TM
# 165        6. Developing region   3. Upper middle income              TN
# 61         6. Developing region   4. Lower middle income              TO
# 227    4. Emerging region: MIKT   3. Upper middle income              TR
# 34         6. Developing region  2. High income: nonOECD              TT
# 60    7. Least developed region   3. Upper middle income              TV
# 225  2. Developed region: nonG7  2. High income: nonOECD              TW
# 168   7. Least developed region            5. Low income              TZ
# 113        6. Developing region   4. Lower middle income              UA
# 166   7. Least developed region            5. Low income              UG
# 36    7. Least developed region            5. Low income              UM
# 57      1. Developed region: G7     1. High income: OECD              US
# 240     5. Emerging region: G20   3. Upper middle income              UY
# 226        6. Developing region   4. Lower middle income              UZ
# 115  2. Developed region: nonG7  2. High income: nonOECD              VA
# 37         6. Developing region   3. Upper middle income              VC
# 243     5. Emerging region: G20   3. Upper middle income              VE
# 38   2. Developed region: nonG7     1. High income: OECD              VG
# 43         6. Developing region  2. High income: nonOECD              VI
# 231     5. Emerging region: G20   4. Lower middle income              VN
# 62    7. Least developed region   4. Lower middle income              VU
# 65         6. Developing region   4. Lower middle income              WF
# 66    7. Least developed region   4. Lower middle income              WS
# 229   7. Least developed region   4. Lower middle income              YE
# 170     5. Emerging region: G20   3. Upper middle income              ZA
# 169   7. Least developed region   4. Lower middle income              ZM
# 171     5. Emerging region: G20            5. Low income              ZW
#
#                   properties.name             properties.sovereignt  \
# 0    Bajo Nuevo Bank (Petrel Is.)      Bajo Nuevo Bank (Petrel Is.)
# 41        Ashmore and Cartier Is.                         Australia
# 42                  Coral Sea Is.                         Australia
# 87                         France                            France
# 94                         Kosovo                            Kosovo
# 26                Serranilla Bank                   Serranilla Bank
# 111                        Norway                            Norway
# 160                    Somaliland                        Somaliland
# 180                      Dhekelia                    United Kingdom
# 182                     N. Cyprus                   Northern Cyprus
# 183       Cyprus U.N. Buffer Zone               Cyprus No Mans Area
# 40            USNB Guantanamo Bay                              Cuba
# 192                      Baikonur                        Kazakhstan
# 187             Indian Ocean Ter.                         Australia
# 218              Scarborough Reef                  Scarborough Reef
# 228                      Akrotiri                    United Kingdom
# 206                   Spratly Is.                   Spratly Islands
# 195               Siachen Glacier                           Kashmir
# 68                        Andorra                           Andorra
# 178          United Arab Emirates              United Arab Emirates
# 172                   Afghanistan                       Afghanistan
# 7               Antigua and Barb.               Antigua and Barbuda
# 1                        Anguilla                    United Kingdom
# 69                        Albania                           Albania
# 174                       Armenia                           Armenia
# 116                        Angola                            Angola
# 232                     Argentina                         Argentina
# 39                 American Samoa          United States of America
# 71                        Austria                           Austria
# 55                      Australia                         Australia
# ..                            ...                               ...
# 222                      Thailand                          Thailand
# 220                    Tajikistan                        Tajikistan
# 221                   Timor-Leste                        East Timor
# 224                  Turkmenistan                      Turkmenistan
# 165                       Tunisia                           Tunisia
# 61                          Tonga                             Tonga
# 227                        Turkey                            Turkey
# 34            Trinidad and Tobago               Trinidad and Tobago
# 60                         Tuvalu                            Tuvalu
# 225                        Taiwan                            Taiwan
# 168                      Tanzania       United Republic of Tanzania
# 113                       Ukraine                           Ukraine
# 166                        Uganda                            Uganda
# 36        U.S. Minor Outlying Is.          United States of America
# 57                  United States          United States of America
# 240                       Uruguay                           Uruguay
# 226                    Uzbekistan                        Uzbekistan
# 115                       Vatican                           Vatican
# 37             St. Vin. and Gren.  Saint Vincent and the Grenadines
# 243                     Venezuela                         Venezuela
# 38             British Virgin Is.                    United Kingdom
# 43                U.S. Virgin Is.          United States of America
# 231                       Vietnam                           Vietnam
# 62                        Vanuatu                           Vanuatu
# 65          Wallis and Futuna Is.                            France
# 66                          Samoa                             Samoa
# 229                         Yemen                             Yemen
# 170                  South Africa                      South Africa
# 169                        Zambia                            Zambia
# 171                      Zimbabwe                          Zimbabwe
#
#        properties.type
# 0        Indeterminate
# 41          Dependency
# 42          Dependency
# 87             Country
# 94   Sovereign country
# 26       Indeterminate
# 111  Sovereign country
# 160      Indeterminate
# 180         Dependency
# 182  Sovereign country
# 183      Indeterminate
# 40               Lease
# 192              Lease
# 187         Dependency
# 218      Indeterminate
# 228         Dependency
# 206      Indeterminate
# 195      Indeterminate
# 68   Sovereign country
# 178  Sovereign country
# 172  Sovereign country
# 7    Sovereign country
# 1           Dependency
# 69   Sovereign country
# 174  Sovereign country
# 116  Sovereign country
# 232  Sovereign country
# 39          Dependency
# 71   Sovereign country
# 55             Country
# ..                 ...
# 222  Sovereign country
# 220  Sovereign country
# 221  Sovereign country
# 224  Sovereign country
# 165  Sovereign country
# 61   Sovereign country
# 227  Sovereign country
# 34   Sovereign country
# 60   Sovereign country
# 225  Sovereign country
# 168  Sovereign country
# 113  Sovereign country
# 166  Sovereign country
# 36          Dependency
# 57             Country
# 240  Sovereign country
# 226  Sovereign country
# 115  Sovereign country
# 37   Sovereign country
# 243  Sovereign country
# 38          Dependency
# 43          Dependency
# 231  Sovereign country
# 62   Sovereign country
# 65          Dependency
# 66   Sovereign country
# 229  Sovereign country
# 170  Sovereign country
# 169  Sovereign country
# 171  Sovereign country
#
# [245 rows x 8 columns]

# %%
trafficking = pandas.read_csv('trafficking.csv',low_memory=False)
trafficking = trafficking.drop(trafficking.columns[[0, 2]], axis=1)
trafficking = trafficking.replace(['-99','18--20', '24--26', '30--38', '21--23',
                           '27--29', '9--17','39--47', '48+', '0--8',
                           'Unknown'], ['Unknown','Adult-', 'Adult', 'Adult', 'Adult',
                                        'Adult', 'Youth', 'Adult', 'Adult+', 'Youth', 
                                            'ZZ'])
trafficking = trafficking.rename(columns={'yearOfRegistration':"Year"})
trafficking = trafficking[['Year', 'gender', 'ageBroad','citizenship','CountryOfExploitation']]
trafficking.head(5)
# Out:
#    Year gender ageBroad citizenship CountryOfExploitation
# 0  2002     ZZ       ZZ          ZZ                    ZZ
# 1  2002     ZZ       ZZ          ZZ                    ZZ
# 2  2002     ZZ       ZZ          ZZ                    ZZ
# 3  2002     ZZ       ZZ          ZZ                    ZZ
# 4  2002     ZZ       ZZ          ZZ                    ZZ

# %%
traffickingCounts = trafficking.groupby(['citizenship', "Year","CountryOfExploitation"],
                 as_index=False).count().iloc[:,:-1]\
                .rename(columns={'citizenship':'properties.code','gender':'CaseCount'})
#                        .set_index(['citizenship', 'Year']) \
traffickingCounts.head()
# Out:
#   properties.code  Year CountryOfExploitation  CaseCount
# 0              AF  2013                    AF         12
# 1              AF  2013                    ZZ         25
# 2              AF  2014                    AF         72
# 3              AF  2014                    ZZ        116
# 4              AF  2015                    SA         14

# %%
longcounts = traffickingCounts[['properties.code', "Year"]].drop_duplicates()
for index,row in traffickingCounts.iterrows():

    col = row[2]
    longcounts.loc[(longcounts['properties.code'] == row[0]) & (longcounts["Year"] == row[1]),
                   "Total"] = traffickingCounts.loc[
                            (traffickingCounts['properties.code'] == row[0]) &
                            (traffickingCounts["Year"] == row[1])]['CaseCount'].sum()

#     EACH COUNTRY

    longcounts.loc[(longcounts['properties.code'] == row[0]) &  (longcounts["Year"] == row[1]),
               col] = traffickingCounts.loc[
                        (traffickingCounts['properties.code'] == row[0]) &
                        (traffickingCounts["Year"] == row[1]) &
                        (traffickingCounts['CountryOfExploitation'] == col)]['CaseCount'].values[0]



longcounts.reset_index().to_json("TraffickingCounts.json", orient="records")

# %%
# Total = traffickingCounts.T.sum().reset_index().rename(columns={0:"TotalTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalFemale = traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('Female')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalFemaleTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalMale = traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('Male')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalMaleTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalChild =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('Child')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalChildTrafficked"})\
# .set_index(['citizenship', 'Year'])


# TotalAdultMinus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('Adult-')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalAdult-Trafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalAdult =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('AdultTraf')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalAdultTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalAdultPlus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('Adult+')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalAdult+Trafficked"})\
# .set_index(['citizenship', 'Year'])


# TotalMaleChild =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('MaleChild')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalMaleChildTrafficked"})\
# .set_index(['citizenship', 'Year'])


# TotalMaleAdultMinus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('MaleAdult-')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalMaleAdult-Trafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalMaleAdult =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('MaleAdultTraf')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalMaleAdultTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalMaleAdultPlus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('MaleAdult+')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalMaleAdult+Trafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalFemaleChild =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('MaleChild')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalFemaleChildTrafficked"})\
# .set_index(['citizenship', 'Year'])


# TotalFemaleAdultMinus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('FemaleAdult-')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalFemaleAdult-Trafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalFemaleAdult =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('FemaleAdultTraf')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalFemaleAdultTrafficked"})\
# .set_index(['citizenship', 'Year'])

# TotalFemaleAdultPlus =  traffickingCounts[traffickingCounts.columns[traffickingCounts \
#                                             .columns.to_series().str.contains('FemaleAdult+')]] \
#                                             .T.sum().reset_index().rename(columns={0:"TotalFemaleAdult+Trafficked"})\
# .set_index(['citizenship', 'Year'])


# FinalTotals = pandas.concat([Total, TotalChild, TotalAdult,
#                  TotalAdultMinus, TotalAdultPlus, TotalFemale, TotalMale,
#                  TotalMaleChild, TotalMaleAdultMinus, TotalMaleAdult, TotalMaleAdultPlus,
#                 TotalFemaleChild,TotalFemaleAdultMinus, TotalFemaleAdult, TotalFemaleAdultPlus],axis=1, join='outer')

# %%
gdp = pandas.read_csv('Countries_GDP_Cleaned.csv')
gdp = pandas.DataFrame(gdp)
gdp = gdp.rename(columns={'Country Code':'properties.code'})
gdp = gdp.rename(columns={'GPD':'GDP(ppp)', 'Country Name':'Name', "Years":'Year'})
gdp.tail()
# Out:
#           Name properties.code  Year      GDP(ppp)
# 6015  Zimbabwe              ZW  2013  3.006463e+10
# 6016  Zimbabwe              ZW  2014  3.125517e+10
# 6017  Zimbabwe              ZW  2015  3.212793e+10
# 6018  Zimbabwe              ZW  2016  3.273816e+10
# 6019  Zimbabwe              ZW  2017  3.447604e+10

# %%
 def colorPick(gdp_md_est):
        

    if gdp_md_est > 1088982000000:
        color = "#7FFF00"
    elif gdp_md_est > 367301000000:
        color = "#98FB98"
    elif gdp_md_est > 171588000000:
        color = "#87CEFA"
    elif gdp_md_est > 71926000000:
        color = "#F0E68C"
    elif gdp_md_est > 34633000000:
        color = "#F4A460"
    elif gdp_md_est > 19688000000:
        color = "#FF4500"
    elif gdp_md_est > 3165000000:
        color = "#8B0000"
    elif type(gdp_md_est) != "float64":
        color = "#FFFFFF"
    
    
    else:
        color = '#FFFFFF'

    return color

# %%
for index,row in gdp.iterrows():
    gdp['color'] = gdp['GDP(ppp)'].apply(colorPick)
gdp.head(5)
# Out:
#           Name properties.code  Year  GDP(ppp)    color
# 0  Afghanistan              AF  1990       0.0  #FFFFFF
# 1  Afghanistan              AF  1991       0.0  #FFFFFF
# 2  Afghanistan              AF  1992       0.0  #FFFFFF
# 3  Afghanistan              AF  1993       0.0  #FFFFFF
# 4  Afghanistan              AF  1994       0.0  #FFFFFF

# %%
TraffickedWithGdp = pandas.merge(longcounts,gdp, on=['properties.code', 'Year'],
                                 how='left').sort_values(['properties.code'])

TraffickedWithGdp.head(25)
longcounts[longcounts['properties.code']=='RU']
# Out:
# Empty DataFrame
# Columns: [properties.code, Year, Total, AF, ZZ, SA, AL, TJ, SN, BG, AR, AE, CY, RU, PL, BY, UG, US, EC, EG, GH, HT, MY, ID, BH, JO, OM, QA, SG, SY, TT, TW, ZA, KZ, TH, MU, CN, KH, Y1, MD, TR, UA, MG, LB, JP, KW, PH, HK, BA, MK, IT, RO, DK, SL, TM, CZ, AT, UZ, VN, MX]
# Index: []
#
# [0 rows x 60 columns]

# %%
TraffickedWithGdp['TraffickingStats'] = [{k:v for k,v in m.items()  \
                                      if pandas.notnull(v)} for m in \
                                     TraffickedWithGdp.iloc[:,2:-3].to_dict(orient='rows')]
    
TraffickedWithGdp = TraffickedWithGdp.drop(TraffickedWithGdp.iloc[:,2:-3], axis=1)
TraffickedWithGdp.head()
# Out:
#   properties.code  Year      GDP(ppp)    color  \
# 0              AF  2013  6.070782e+10  #F4A460
# 1              AF  2014  6.345999e+10  #F4A460
# 2              AF  2015  6.498854e+10  #F4A460
# 3              AL  2005  1.789692e+10  #8B0000
# 4              BD  2015  5.380000e+11  #98FB98
#
#                             TraffickingStats
# 0    {'AF': 12.0, 'ZZ': 25.0, 'Total': 37.0}
# 1  {'AF': 72.0, 'ZZ': 116.0, 'Total': 188.0}
# 2                {'SA': 14.0, 'Total': 14.0}
# 3                {'AL': 45.0, 'Total': 45.0}
# 4                {'TJ': 11.0, 'Total': 11.0}

# %%
def halfwayPoints(df, column):
    allMidPoints = []
    for _, row in df.iterrows():
        midPoints = []
        lastcoord = 0
        counter = 0
        for coord in row[column][0]:
                print(coord)
                
                if lastcoord != coord and len(coord) == 2:
                    lastcoord = coord

                    midpoint = [float(lastcoord[0])+float(coord[0]) * 0.5,
                                 float(lastcoord[1]), float(coord[1]) * 0.5 ]
            
                    midPoints.append(midpoint)
                elif  lastcoord != coord[0]:
                    lastcoord = coord[0]

                    midpoint = [float(lastcoord[0])+float(coord[0][0]) * 0.5,
                                 float(lastcoord[1]), float(coord[0][1]) * 0.5 ]
            
                    midPoints.append(midpoint)

        allMidPoints.append(midPoints)
    return allMidPoints

# %%
globeFinal = pandas.merge(TraffickedWithGdp, globe, on="properties.code", how="outer")
globeFinal['GDP(ppp)'] = globeFinal['GDP(ppp)'].fillna(-99)
globeFinal['Year'] = globeFinal['Year'].fillna(-99)
globeFinal['color'] = globeFinal['color'].fillna("#708090")
globeFinal = globeFinal[globeFinal['properties.code'] != "ZZ"]
globeFinal = globeFinal[globeFinal['properties.code'] != "-99"]
globeFinal['TraffickingStats'] = globeFinal['TraffickingStats'].fillna("None")

# %%
globeFinal[globeFinal.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [properties.code, Year, GDP(ppp), color, TraffickingStats, geometry.coordinates, geometry.type, properties.economy, properties.income_grp, properties.name, properties.sovereignt, properties.type]
# Index: []

# %%
globeFinal.head()
# Out:
#   properties.code    Year      GDP(ppp)    color  \
# 0              AF  2013.0  6.070782e+10  #F4A460
# 1              AF  2014.0  6.345999e+10  #F4A460
# 2              AF  2015.0  6.498854e+10  #F4A460
# 3              AL  2005.0  1.789692e+10  #8B0000
# 4              BD  2015.0  5.380000e+11  #98FB98
#
#                             TraffickingStats  \
# 0    {'AF': 12.0, 'ZZ': 25.0, 'Total': 37.0}
# 1  {'AF': 72.0, 'ZZ': 116.0, 'Total': 188.0}
# 2                {'SA': 14.0, 'Total': 14.0}
# 3                {'AL': 45.0, 'Total': 45.0}
# 4                {'TJ': 11.0, 'Total': 11.0}
#
#                                 geometry.coordinates geometry.type  \
# 0  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 1  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 2  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 3  [[[19.747765747000074, 42.57890085900007], [19...       Polygon
# 4  [[[[91.9387313160001, 21.714829820000105], [91...  MultiPolygon
#
#           properties.economy   properties.income_grp properties.name  \
# 0  7. Least developed region           5. Low income     Afghanistan
# 1  7. Least developed region           5. Low income     Afghanistan
# 2  7. Least developed region           5. Low income     Afghanistan
# 3       6. Developing region  4. Lower middle income         Albania
# 4  7. Least developed region           5. Low income      Bangladesh
#
#   properties.sovereignt    properties.type
# 0           Afghanistan  Sovereign country
# 1           Afghanistan  Sovereign country
# 2           Afghanistan  Sovereign country
# 3               Albania  Sovereign country
# 4            Bangladesh  Sovereign country

# %%
# dist = math.hypot(x2 - x1, y2 - y1)
def arrowPath (df):
    path_coords = []

    for _, row in df.iterrows():
        path_coord = []
        shortest_path = 4e8
        
        if row['TraffickingStats'] != "None":
            for code in row['TraffickingStats']:
                if code != "ZZ" and code !=  "Total" and code != row['properties.code']:
                    try:
    
                        originCoords = row['geometry.coordinates']
                        destinationCoords = df[df['properties.code']==code]['geometry.coordinates']

                        for polygonA in originCoords:
                            for polygonB in destinationCoords:
    
                                while len(polygonA[0]) != 2 or len(polygonA) == 1:
                                    polygonA = polygonA[0]

                                while len(polygonB[0]) != 2 or len(polygonB) == 1:
                                    polygonB = polygonB[0]

                                for origin in polygonA:
                                    for destination in polygonB:
                                        path =  math.hypot(destination[0] - origin[0],
                                                       destination[1] - origin[1])
                                        if path < shortest_path and path != 0:
                                            shortest_path=path
                                            path_coord = [code, origin, destination, 
                                                          row['TraffickingStats'][code]]

                    except IndexError:
                        print("No coords for", row['properties.code'], code )
                    except KeyError:
                        print("No coords for", row['properties.code'], code )
        path_coords.append(path_coord)
        
    return(path_coords)

# %%
globeFinal['arrowPath'] = arrowPath(globeFinal)

# %%
globeFinal.head()
# Out:
#   properties.code    Year      GDP(ppp)    color  \
# 0              AF  2013.0  6.070782e+10  #F4A460
# 1              AF  2014.0  6.345999e+10  #F4A460
# 2              AF  2015.0  6.498854e+10  #F4A460
# 3              AL  2005.0  1.789692e+10  #8B0000
# 4              BD  2015.0  5.380000e+11  #98FB98
#
#                             TraffickingStats  \
# 0    {'AF': 12.0, 'ZZ': 25.0, 'Total': 37.0}
# 1  {'AF': 72.0, 'ZZ': 116.0, 'Total': 188.0}
# 2                {'SA': 14.0, 'Total': 14.0}
# 3                {'AL': 45.0, 'Total': 45.0}
# 4                {'TJ': 11.0, 'Total': 11.0}
#
#                                 geometry.coordinates geometry.type  \
# 0  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 1  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 2  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 3  [[[19.747765747000074, 42.57890085900007], [19...       Polygon
# 4  [[[[91.9387313160001, 21.714829820000105], [91...  MultiPolygon
#
#           properties.economy   properties.income_grp properties.name  \
# 0  7. Least developed region           5. Low income     Afghanistan
# 1  7. Least developed region           5. Low income     Afghanistan
# 2  7. Least developed region           5. Low income     Afghanistan
# 3       6. Developing region  4. Lower middle income         Albania
# 4  7. Least developed region           5. Low income      Bangladesh
#
#   properties.sovereignt    properties.type  \
# 0           Afghanistan  Sovereign country
# 1           Afghanistan  Sovereign country
# 2           Afghanistan  Sovereign country
# 3               Albania  Sovereign country
# 4            Bangladesh  Sovereign country
#
#                                            arrowPath
# 0                                                 []
# 1                                                 []
# 2  [SA, [60.844378703000075, 29.858178610000067],...
# 3                                                 []
# 4  [TJ, [88.37251753700016, 26.61160675100011], [...

# %%
def df_to_geojson(df, properties):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type': [],'coordinates':[]}}
        feature['geometry']['coordinates'] = row['geometry.coordinates']
        feature['geometry']['type'] = row['geometry.type']
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
nestedglobe['features'][0]
# Out:
# {"geometry": {"coordinates": [[[-79.98928788999987, 15.794948635000056], [-79.9878230459999, 15.796210028000074], [-79.98639889199991, 15.794419664000086], [-79.98814856699991, 15.79417552300012], [-79.98928788999987, 15.794948635000056]]], "type": "Polygon"}, "properties": {"abbrev": null, "abbrev_len": 0, "adm0_a3": "BJN", "adm0_a3_is": "-99", "adm0_a3_un": -99, "adm0_a3_us": "B41", "adm0_a3_wb": -99, "adm0_dif": 0, "admin": "Bajo Nuevo Bank (Petrel Is.)", "brk_a3": "B41", "brk_diff": 1, "brk_group": null, "brk_name": "Bajo Nuevo Bank (Petrel Is.)", "continent": "North America", "economy": "7. Least developed region", "featurecla": "Admin-0 country", "filename": "bajonuevobankpetrelis.geojson", "fips_10_": "-99", "formal_en": null, "formal_fr": null, "gdp_md_est": -99, "gdp_year": 2012, "geou_dif": 0, "geounit": "Bajo Nuevo Bank (Petrel Is.)", "gu_a3": "BJN", "homepart": 1, "income_grp": "5. Low income", "iso_a2": "-99", "iso_a3": "-99", "iso_n3": "-99", "labelrank": 8, "lastcensus": -99, "level": 2, "long_len": 32, "mapcolor13": -99, "mapcolor7": 3, "mapcolor8": 7, "mapcolor9": 6, "name": "Bajo Nuevo Bank (Petrel Is.)", "name_alt": null, "name_len": 28, "name_long": "Bajo Nuevo Bank (Petrel Islands)", "name_sort": "Bajo Nuevo Bank (Petrel Is.)", "note_adm0": "Disputed", "note_brk": "Claimed by Columbia, Jamaica, Nicaragua and the United States", "pop_est": -99, "pop_year": 2012, "postal": null, "region_un": "Americas", "region_wb": "Latin America & Caribbean", "scalerank": 6, "sov_a3": "BJN", "sovereignt": "Bajo Nuevo Bank (Petrel Is.)", "su_a3": "BJN", "su_dif": 0, "subregion": "Caribbean", "subunit": "Bajo Nuevo Bank (Petrel Is.)", "tiny": -99, "type": "Indeterminate", "un_a3": "-099", "wb_a2": "-99", "wb_a3": "-99", "wikipedia": -99, "woe_id": -99, "woe_id_eh": -99, "woe_note": "No WOE equivalent."}, "type": "Feature"}

# %%
cols = ['properties.code', 'GDP(ppp)', 'color','TraffickingStats','Year', 
        'properties.economy', 'properties.income_grp', 'properties.name',
        'properties.sovereignt', 'properties.type', 'arrowPath']

# %%
for year in globeFinal['Year'].unique():
#     year = str(year)
    with open("../static/data/globe%s.geo.json" %str(year).replace(".0", ""),  'w', encoding='utf-8') as f:
        json.dump(df_to_geojson(globeFinal[globeFinal['Year']==int(year)], cols), f, ensure_ascii=False)

# %%
cols = ['properties.code', 'GDP(ppp)', 'color','TraffickingStats', 
        'properties.economy', 'properties.income_grp', 'properties.name',
        'properties.sovereignt', 'properties.type', ]

noData = globeFinal[globeFinal['TraffickingStats']=='None']
noData = noData

with open('../static/data/noshare.geo.json', 'w', encoding='utf-8') as f:
    json.dump(df_to_geojson(noData, cols), f, ensure_ascii=False)

# %%
"y2U3gQBgiV8Kq2u"
"traffickadmin"

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://traffickAdmin:y2U3gQBgiV8Kq2u@traffickcluster-shard-00-00-xeuqd.mongodb.net:27017,traffickcluster-shard-00-01-xeuqd.mongodb.net:27017,traffickcluster-shard-00-02-xeuqd.mongodb.net:27017/test?ssl=true&replicaSet=TraffickCluster-shard-0&authSource=admin&retryWrites=true")

# %%
db = client.TraffickDB
Trafficking = db.trafficking

# %%
cols = ['code', 'GDP(ppp)', 'color','TraffickingStats','Year', 
        'economy', 'income_grp', 'name',
        'sovereignt', 'type', 'arrowPath']
globeFinal['Year'] = globeFinal['Year'].astype('int')
globeFinal = globeFinal.rename(columns={'properties.code':'code',
        'properties.economy': 'economy', 'properties.income_grp' : 'income_grp', 'properties.name': 'name',
        'properties.sovereignt' : 'sovereignt', 'properties.type' : 'type'})
globeFinal.head()
# Out:
#   code  Year      GDP(ppp)    color  \
# 0   AF  2013  6.070782e+10  #F4A460
# 1   AF  2014  6.345999e+10  #F4A460
# 2   AF  2015  6.498854e+10  #F4A460
# 3   AL  2005  1.789692e+10  #8B0000
# 4   BD  2015  5.380000e+11  #98FB98
#
#                             TraffickingStats  \
# 0    {'AF': 12.0, 'ZZ': 25.0, 'Total': 37.0}
# 1  {'AF': 72.0, 'ZZ': 116.0, 'Total': 188.0}
# 2                {'SA': 14.0, 'Total': 14.0}
# 3                {'AL': 45.0, 'Total': 45.0}
# 4                {'TJ': 11.0, 'Total': 11.0}
#
#                                 geometry.coordinates geometry.type  \
# 0  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 1  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 2  [[[71.04980228700008, 38.40866445000009], [71....       Polygon
# 3  [[[19.747765747000074, 42.57890085900007], [19...       Polygon
# 4  [[[[91.9387313160001, 21.714829820000105], [91...  MultiPolygon
#
#                      economy              income_grp         name  \
# 0  7. Least developed region           5. Low income  Afghanistan
# 1  7. Least developed region           5. Low income  Afghanistan
# 2  7. Least developed region           5. Low income  Afghanistan
# 3       6. Developing region  4. Lower middle income      Albania
# 4  7. Least developed region           5. Low income   Bangladesh
#
#     sovereignt               type  \
# 0  Afghanistan  Sovereign country
# 1  Afghanistan  Sovereign country
# 2  Afghanistan  Sovereign country
# 3      Albania  Sovereign country
# 4   Bangladesh  Sovereign country
#
#                                            arrowPath
# 0                                                 []
# 1                                                 []
# 2  [SA, [60.844378703000075, 29.858178610000067],...
# 3                                                 []
# 4  [TJ, [88.37251753700016, 26.61160675100011], [...

# %%
finalJson = df_to_geojson(globeFinal, cols)
# for feature in finalJson['features']:
Trafficking.insert_many(finalJson['features'])

# %%
for result in Trafficking.find({"properties.Year" : 2013}):
    print(result)
# Out:
# {'properties': {'code': 'AF', 'Year': 2013, 'income_grp': '5. Low income', 'color': '#F4A460', 'TraffickingStats': {'AF': 12.0, 'ZZ': 25.0, 'Total': 37.0}, 'economy': '7. Least developed region', 'sovereignt': 'Afghanistan', 'type': 'Sovereign country', 'arrowPath': [], 'name': 'Afghanistan', 'GDP(ppp)': 60707816635.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e425'), 'geometry': {'type': 'Polygon', 'coordinates': [[[71.04980228700008, 38.40866445000009], [71.05714034000005, 38.40902618400008], [71.0649434820001, 38.411816712000046], [71.07698409100004, 38.41217844700014], [71.0893864340001, 38.409853007], [71.11739506000004, 38.39863922100008], [71.15594567900013, 38.376211650000066], [71.21769901600008, 38.325827128000064], [71.3001229250001, 38.29869700100011], [71.3343843990001, 38.28066192700001], [71.35815555800013, 38.25125803700013], [71.36451176000007, 38.206816305000046], [71.35908573400013, 38.18410451300007], [71.34094730600009, 38.14092885400004], [71.33453942900013, 38.11167999300011], [71.31603926600013, 38.08328379300008], [71.3023966880001, 38.04233022100007], [71.27263106300012, 37.997991842], [71.26591312700008, 37.97254119900009], [71.25578454600003, 37.94988108300004], [71.25454431200012, 37.93928741500005], [71.25826501500012, 37.92647165900007], [71.26353601100004, 37.9243529260001], [71.27118412300011, 37.9261874390001], [71.28182946800011, 37.92499888100007], [71.31975996900013, 37.90058176700003], [71.34115401300005, 37.89329539000008], [71.36099776200012, 37.90202870700003], [71.37918786600005, 37.91293243400008], [71.50119592300013, 37.94621205700014], [71.5370593670001, 37.944455058000074], [71.56734175700012, 37.92807362900001], [71.59772749900003, 37.898359681000045], [71.59028609300003, 37.891435038000054], [71.59338667800006, 37.87934275300006], [71.59504032400014, 37.85753529900006], [71.59421350100007, 37.833764140000085], [71.59028609300003, 37.815729065000085], [71.57467981000008, 37.79800404900007], [71.53778283700007, 37.779038798000016], [71.52951460800011, 37.76113291500005], [71.53116825400008, 37.751753642], [71.54026330600004, 37.73051462900014], [71.54253706900005, 37.71955922500007], [71.54088342300007, 37.70971486500008], [71.52951460800011, 37.67857981400002], [71.52476037600013, 37.64772898400013], [71.52207320200012, 37.637626241000106], [71.51721561700008, 37.62922882100011], [71.5051233320001, 37.615999655000024], [71.50150598200008, 37.61034108500007], [71.49716516100011, 37.56654530900008], [71.51122115100003, 37.48587839800007], [71.50150598200008, 37.44577748700007], [71.49024052000004, 37.42337575300007], [71.4871399330001, 37.4090872190001], [71.49468469200013, 37.37069163100006], [71.49654504400007, 37.328523662000094], [71.49385787000011, 37.30754303], [71.48786340400011, 37.2949856570001], [71.48703658000005, 37.26705454600011], [71.45013960700004, 37.216670024000024], [71.45375695800004, 37.19261464500008], [71.44683231600004, 37.18359710700014], [71.44104455600007, 37.1684300740001], [71.43318973800012, 37.12734731100005], [71.43112268100009, 37.06698923700014], [71.43318973800012, 37.05474192400004], [71.43918420400007, 37.04409657800002], [71.45644413300005, 37.02254750600008], [71.45995813000012, 37.01073944100005], [71.45995813000012, 36.969785868000145], [71.46305871600009, 36.94808176700013], [71.47174035600011, 36.93004669200013], [71.52848107900013, 36.856149394000056], [71.53850630700008, 36.8360989380001], [71.5453275960001, 36.79000356100008], [71.55287235600008, 36.76959137000006], [71.56393111200008, 36.750677796000105], [71.57736698400004, 36.73326283800009], [71.6110600180001, 36.704840800000056], [71.65302128100006, 36.68701243100011], [71.69994348200004, 36.67864084900011], [71.74851932800004, 36.67864084900011], [71.79761193900009, 36.686082255000144], [71.83657596900012, 36.6991563920001], [72.12668746000007, 36.87273752900006], [72.15283573400006, 36.89570770300011], [72.1868388260001, 36.91139150000006], [72.19593387900011, 36.91 ...
# {'properties': {'code': 'BY', 'Year': 2013, 'income_grp': '3. Upper middle income', 'color': '#87CEFA', 'TraffickingStats': {'BY': 301.0, 'Total': 301.0}, 'economy': '6. Developing region', 'sovereignt': 'Belarus', 'type': 'Sovereign country', 'arrowPath': [], 'name': 'Belarus', 'GDP(ppp)': 173000000000.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e432'), 'geometry': {'type': 'Polygon', 'coordinates': [[[28.148906697000115, 56.14241404300008], [28.169112182000106, 56.12525746700001], [28.238461955000048, 56.08262441000002], [28.269364462000055, 56.05820729600009], [28.2898283290001, 56.04660593700004], [28.310912313000127, 56.04267852800006], [28.333443238000143, 56.05024912500005], [28.366516154000124, 56.07911041300008], [28.389770548000058, 56.08856720000006], [28.537823527000086, 56.09771392800013], [28.59471927900003, 56.09239125600007], [28.61146244300008, 56.08846384700009], [28.620712524000112, 56.08298614600002], [28.637093954000132, 56.065726217000126], [28.671923868000107, 56.03756256100007], [28.680605510000078, 56.02738230500012], [28.69001062000012, 56.003895365000034], [28.695488322000106, 55.980150045000066], [28.70639205000009, 55.95984120700007], [28.731920207000112, 55.946792908000106], [28.808969767000065, 55.93457143200009], [28.830880574000105, 55.93767201800006], [28.83305098500009, 55.960978089000065], [28.859716024000136, 55.976455180000066], [28.922141154000084, 55.99213897700014], [28.92224450700013, 55.99219065400006], [28.922296184000057, 55.99219065400006], [28.922451212000087, 55.99224233000007], [28.980845581000064, 56.01353302000007], [29.030765015000014, 56.02417836600006], [29.088642619000037, 56.0232223510001], [29.145435018000082, 56.01203440400005], [29.192925660000075, 55.99213897700014], [29.224034871000125, 55.97818634100013], [29.37741052300009, 55.954027608000075], [29.39560062700013, 55.947723084000074], [29.413067261000094, 55.93798207600011], [29.431567423000104, 55.92418446900007], [29.441075887000185, 55.91493438700007], [29.444434855000107, 55.90692454000009], [29.440559123000067, 55.900542502000064], [29.43373783300012, 55.89953481100008], [29.4255729570001, 55.899999898], [29.417408081000076, 55.89801035600007], [29.40779626500006, 55.893876242000054], [29.399631388000046, 55.89188669900011], [29.39198327700007, 55.88837270100006], [29.384128459000124, 55.87994944300007], [29.380717814000093, 55.871241964000085], [29.37565352400014, 55.84679901200005], [29.37193282100009, 55.836386210000114], [29.348161662000052, 55.8028482060001], [29.34361413500011, 55.78698354100009], [29.35074548300014, 55.7660545860001], [29.363406209000118, 55.75148183200005], [29.413067261000094, 55.72776235], [29.461022990000117, 55.68729970300012], [29.48086674000012, 55.681098532000135], [29.508100219000085, 55.685491028000115], [29.585356486000077, 55.73802012100009], [29.684161825000047, 55.77060211200006], [29.71082686400007, 55.7737543740001], [29.779866577000064, 55.7638066610001], [29.805704794000064, 55.77145477400009], [29.844772176000106, 55.81256337500014], [29.869473511000077, 55.83054677400014], [29.90781742300004, 55.843207500000084], [29.94771162900014, 55.84819427600013], [29.988225952000047, 55.84679901200005], [30.106254924000037, 55.8219168090001], [30.13235152200014, 55.82687774700014], [30.17725834200013, 55.851372376000086], [30.200254353000105, 55.8579869590001], [30.21777266400005, 55.85514475500011], [30.251517375000105, 55.83762644500007], [30.270792684000128, 55.83065012700007], [30.468816773000125, 55.79352061000009], [30.477395060000106, 55.78773285000011], [30.477808472000106, 55.77912872400006], [30.471814005000056, 55.77096384700005], [30.46928186100007, 55.76264394200009], [30.480702351000104, 55.75396230100002], [30.56958581500004, 55.72951934900009], [30.5801278080001, 55.72476511700009], [30.58746586100011, 55.71830556300006], [30.591599975000122, 55.705696513000106], [30.588396037000052, 55.69660146100006], [30.583745158000056, 55.68853993800005], [3 ...
# {'properties': {'code': 'HT', 'Year': 2013, 'income_grp': '5. Low income', 'color': '#8B0000', 'TraffickingStats': {'HT': 54.0, 'Total': 54.0}, 'economy': '7. Least developed region', 'sovereignt': 'Haiti', 'type': 'Sovereign country', 'arrowPath': [], 'name': 'Haiti', 'GDP(ppp)': 17589763725.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e44a'), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-73.69424394399988, 18.106878973000093], [-73.68785559799994, 18.100490627000156], [-73.67638098899991, 18.108099677], [-73.67088782499988, 18.105373440000122], [-73.66690019399991, 18.098578192], [-73.6599828769999, 18.094224351000108], [-73.62889563699991, 18.094224351000108], [-73.61204993399991, 18.09324778900013], [-73.59227454299989, 18.089341539000046], [-73.57799231699988, 18.081122137000037], [-73.57799231699988, 18.06696198100012], [-73.59044348899991, 18.059393622000172], [-73.61082923099988, 18.057562567], [-73.6497289699999, 18.059475002000156], [-73.66722571499994, 18.063137111000103], [-73.68252519399991, 18.072007554000052], [-73.70767167899987, 18.094224351000108], [-73.7044571609999, 18.104193427], [-73.69994055899986, 18.108303127000156], [-73.69424394399988, 18.106878973000093]]], [[[-73.71458899599989, 18.60130442900005], [-73.73761959499984, 18.588202216000084], [-73.76952063699986, 18.58836497600005], [-73.79442298099991, 18.601874091000028], [-73.79649817599991, 18.628648179000137], [-73.7726944649999, 18.639349677000055], [-73.73997962099989, 18.63686758000013], [-73.71495520699989, 18.623480536000113], [-73.71458899599989, 18.60130442900005]]], [[[-72.8204646479999, 18.70066966400016], [-72.8311254549999, 18.696437893000123], [-72.8382055329999, 18.70258209800012], [-72.8471573559999, 18.72052643400015], [-72.85570227799994, 18.727687893], [-72.86335201699987, 18.729641018000066], [-72.88589433499996, 18.731024481000034], [-72.97500566299993, 18.749904690000065], [-73.00544186099998, 18.75214264500015], [-73.03742428299998, 18.759588934000035], [-73.12555904899989, 18.813625393000123], [-73.21458899599989, 18.836615302], [-73.23851477799985, 18.851507880000057], [-73.25865637899989, 18.878485419000114], [-73.27733313699986, 18.89109935099999], [-73.28258216099992, 18.895493882000082], [-73.28990637899994, 18.904201565000065], [-73.2965388659999, 18.914496161000088], [-73.2996313139999, 18.92552317900011], [-73.2962133449999, 18.936509507], [-73.28384355399996, 18.949693101000136], [-73.2663468089999, 18.96084219000015], [-73.24596106699991, 18.968410549000012], [-73.22447669199991, 18.971258856000034], [-73.20079505099997, 18.968695380000142], [-73.06191972599993, 18.91331614800005], [-72.99339758999989, 18.892035223000065], [-72.9172257149999, 18.85545482000005], [-72.84609941299996, 18.827093817], [-72.8170466789999, 18.79311758000007], [-72.80947831899994, 18.771470445000162], [-72.80589758999986, 18.745672919000143], [-72.8087458979999, 18.720404364], [-72.8204646479999, 18.70066966400016]]], [[[-72.77603105399987, 19.943915106000063], [-72.6739802729999, 19.92137278900016], [-72.6488337879999, 19.906642971000068], [-72.62804114499991, 19.897284247000027], [-72.56871497299994, 19.879868882000082], [-72.56517493399988, 19.875718492000132], [-72.5443416009999, 19.851263739], [-72.51756751199989, 19.834133205000157], [-72.48973548099994, 19.824652411000145], [-72.47443600199998, 19.834051825000174], [-72.4562068349999, 19.824855861000103], [-72.4259333979999, 19.813788153000143], [-72.39757239499997, 19.80695221600014], [-72.38508053299994, 19.810451565000122], [-72.37873287699992, 19.794663804], [-72.3304337229999, 19.75210195500013], [-72.3304337229999, 19.745835679], [-72.33519446499989, 19.74787018400012], [-72.35090084499987, 19.75210195500013], [-72.33824622299989, 19.722967841000084], [-72.33385169199991, 19.718573309000092], [-72.31615149599992, 19.714829820000077], [-72.31240800699987, 19.716131903000147], [-72.31615149599992, 19.724798895000063], [-72.30308997299991, 19.7390811220 ...
# {'properties': {'code': 'LK', 'Year': 2013, 'income_grp': '4. Lower middle income', 'color': '#87CEFA', 'TraffickingStats': {'JO': 53.0, 'Total': 53.0}, 'economy': '6. Developing region', 'sovereignt': 'Sri Lanka', 'type': 'Sovereign country', 'arrowPath': ['JO', [79.65870201900012, 9.555365302000096], [39.29199914500015, 32.24451873800007], 53.0], 'name': 'Sri Lanka', 'GDP(ppp)': 218000000000.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e464'), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[81.82260175900008, 7.491359768000152], [81.80779056100008, 7.479193427000084], [81.79371178500011, 7.490220445000118], [81.7893986340001, 7.494737046000168], [81.78736412900015, 7.496812242000189], [81.78671308700021, 7.501776434000148], [81.7859806650001, 7.506699937000107], [81.7859806650001, 7.506740627000099], [81.78614342500006, 7.508775132000125], [81.79029381600016, 7.571722723000065], [81.78736412900015, 7.593451239000131], [81.77637780000012, 7.602728583000086], [81.77222741000016, 7.611639716000127], [81.73878014400012, 7.660467841000127], [81.73707116000011, 7.670965887000094], [81.7331649100001, 7.679103908000116], [81.7283634770001, 7.689113674000096], [81.72510826900006, 7.698919989000132], [81.72559655000006, 7.709295966000126], [81.72868899800008, 7.718491929000095], [81.72999108200023, 7.728176174000154], [81.72999108200023, 7.728216864000145], [81.72510826900006, 7.739813544000157], [81.72510826900006, 7.739935614000131], [81.73796634200019, 7.727484442000119], [81.75025475400017, 7.698635158000101], [81.75928795700005, 7.685288804000081], [81.76148522200006, 7.679510809000121], [81.770762566, 7.654689846000153], [81.79509524800008, 7.61627838700015], [81.80632571700019, 7.598578192000147], [81.82325280000006, 7.511379299000126], [81.82325280000006, 7.511297919000142], [81.82260175900008, 7.491359768000152]]], [[[79.88233483200023, 9.053778387000179], [79.91651451900012, 9.020982164000158], [79.91643313900012, 9.021022854000151], [79.900075717, 9.024400132000082], [79.8712671230002, 9.038560289000188], [79.8543400400001, 9.041489976000122], [79.88030032600008, 9.012193101000108], [79.9007267590001, 8.989081122000144], [79.9096785820001, 8.973211981000118], [79.88575280000006, 8.976223049000126], [79.87012780000006, 8.98818594000015], [79.85938561300006, 9.001206773000149], [79.851328972, 9.007391669000114], [79.84099368600019, 9.012600002000113], [79.79981530000005, 9.0489769550001], [79.77938886800004, 9.058010158000101], [79.75896243600019, 9.067043361000117], [79.74398847700016, 9.071071682000166], [79.73601321700019, 9.073228257000082], [79.71412194100017, 9.075628973000121], [79.70297285200016, 9.079982815000122], [79.69800866000011, 9.089585679000095], [79.70118248800006, 9.099188544000171], [79.71412194100017, 9.103583075000145], [79.75879967500012, 9.103583075000145], [79.77857506600006, 9.098537502000127], [79.79900149800012, 9.093329169000128], [79.84164472700016, 9.07721588700015], [79.88233483200023, 9.053778387000179]]], [[[79.71469160200016, 9.485052802000084], [79.68946373800006, 9.483587958000115], [79.66602623800011, 9.491278387000136], [79.65577233200005, 9.50389232000012], [79.65577233200005, 9.544867255000128], [79.65870201900012, 9.555365302000096], [79.66529381600017, 9.554022528000116], [79.67212975400017, 9.545599677000068], [79.67628014400012, 9.53497955900012], [79.69353274800002, 9.529608466000155], [79.71412194100017, 9.528062242000118], [79.71924889400006, 9.524359442000074], [79.7308048840001, 9.500189520000077], [79.7308048840001, 9.500148830000086], [79.72282962300008, 9.492621161000116], [79.71469160200016, 9.485052802000084]]], [[[79.90284264400012, 9.678941148000192], [79.9070744150001, 9.677883205000143], [79.92644290500002, 9.678941148000192], [79.92969811300006, 9.67597077000009], [79.93116295700023, 9.660956122000158], [79.93360436300004, 9.654730536000102], [79.94499759200002, 9.647609768000152], [79.96045983200017, 9.641058661000073], [79.97339928500017, 9.6 ...
# {'properties': {'code': 'MD', 'Year': 2013, 'income_grp': '4. Lower middle income', 'color': '#8B0000', 'TraffickingStats': {'ZZ': 256.0, 'MD': 630.0, 'Total': 886.0}, 'economy': '6. Developing region', 'sovereignt': 'Moldova', 'type': 'Sovereign country', 'arrowPath': [], 'name': 'Moldova', 'GDP(ppp)': 16726094467.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e465'), 'geometry': {'type': 'Polygon', 'coordinates': [[[27.60687259900004, 48.457818502000165], [27.627026408000116, 48.451255595000084], [27.75177331500009, 48.45197906599999], [27.785259643000103, 48.44156626400014], [27.849855184000063, 48.40963022900017], [27.864841349000127, 48.39890736900015], [27.885371499000144, 48.378443876000134], [27.896674032000078, 48.36717804000013], [27.904528849000116, 48.36247548400014], [27.92643965600007, 48.3394277950001], [27.96705733200011, 48.32888580400014], [28.003176857000113, 48.325882843], [28.055940796000044, 48.32149607400014], [28.07640466300012, 48.31493316700014], [28.092837768000066, 48.30206573500005], [28.098315471000063, 48.28410817500015], [28.078678426000124, 48.24491160100003], [28.093251180000095, 48.237444357000086], [28.115575399000136, 48.236746725], [28.131078329000076, 48.23958892899999], [28.162084188000076, 48.25718475400005], [28.17851729300014, 48.258864238000015], [28.18575199400004, 48.24237945600013], [28.189369344000113, 48.223052470000184], [28.19991133600007, 48.211735332], [28.216964559000104, 48.208143820000124], [28.240322307000042, 48.21163197900007], [28.261716349000064, 48.21995188400014], [28.277529337000146, 48.22912445100003], [28.294479207000077, 48.23648834300003], [28.3405745850001, 48.2401056930001], [28.35773116100006, 48.238607076], [28.368169800000086, 48.23062306800012], [28.370030151000094, 48.21163197900007], [28.36336389200008, 48.191013082000076], [28.352253458000064, 48.18186635400009], [28.337887410000064, 48.17548431500016], [28.322177775000082, 48.16321116100012], [28.3155631920001, 48.14928436300011], [28.317423543000103, 48.135357565000064], [28.328585653000115, 48.12701182000008], [28.349566284000048, 48.129724833000026], [28.364965861000112, 48.14150706000011], [28.3755595290001, 48.156648255000114], [28.388633667000136, 48.168585511000074], [28.411578003000074, 48.17070424400005], [28.427287639000042, 48.16336619100015], [28.43689945500006, 48.14985280399999], [28.435659221000037, 48.13468577100015], [28.4190194090001, 48.122231751000086], [28.44744144700013, 48.08275095700015], [28.459378703000084, 48.0744568890001], [28.479584188000075, 48.064922588000016], [28.490022827000104, 48.06549102800007], [28.493743531000092, 48.074818624], [28.494156942000103, 48.09184600900012], [28.499790098000087, 48.10891363000012], [28.501081584000104, 48.11282664000014], [28.501113053000125, 48.11288926600015], [28.51932336400006, 48.1491293340001], [28.54159590600011, 48.15595062300007], [28.573635295000113, 48.154968771000185], [28.665619344000106, 48.129337260000014], [28.735072469000073, 48.12869130500006], [28.771245972000113, 48.12445383699999], [28.799254598000115, 48.11179311100015], [28.80592085800004, 48.103809103000074], [28.808349650000082, 48.096574402000115], [28.809176473, 48.089778952000174], [28.811553589000138, 48.08290598600011], [28.827573283000103, 48.057016094000076], [28.83077722100009, 48.03086781900008], [28.83253422100006, 48.024821676000116], [28.839252156000068, 48.018284607000126], [28.855685262000065, 48.00792348300002], [28.862085148000062, 48.00050207700015], [28.882557007000056, 47.97676259400008], [28.914803101000103, 47.95314646400005], [28.936086736000046, 47.94216435599999], [28.95035648600006, 47.934801331000145], [28.980845581000064, 47.92637807199999], [29.017225790000055, 47.931080628000146], [29.061047404000135, 47.96976043800005], [29.092725057000052, 47.98017323800009], [29.11003666200014, 47.97965647400006], [29.12398929800014, 47.97598744700015], [29.136288290000092, 47.96818430600002], [29.147967163000146, 47.95536855100015 ...
# {'properties': {'code': 'MM', 'Year': 2013, 'income_grp': '5. Low income', 'color': '#87CEFA', 'TraffickingStats': {'ID': 29.0, 'Total': 29.0}, 'economy': '7. Least developed region', 'sovereignt': 'Myanmar', 'type': 'Sovereign country', 'arrowPath': ['ID', [98.56055748800006, 10.002142645000104], [121.52719160200006, -10.629571221999825], 29.0], 'name': 'Myanmar', 'GDP(ppp)': 237000000000.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e47b'), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[98.0574650400001, 9.79686107000012], [98.03760826900006, 9.790716864000132], [98.01832116000006, 9.794907945000162], [98.00806725400011, 9.807440497000158], [98.015391472, 9.826402085000081], [98.03028405000006, 9.833400783000158], [98.04607181100013, 9.82794830900012], [98.05689537900011, 9.814357815000065], [98.0574650400001, 9.79686107000012]]], [[[98.25440514400012, 10.062689520000092], [98.27515709700012, 10.055650132000123], [98.27963300900015, 10.058661200000131], [98.282481316, 10.059393622000158], [98.29566491000006, 10.055650132000123], [98.29566491000006, 10.048895575000174], [98.28003991000016, 10.051011460000096], [98.27393639400005, 10.048041083000086], [98.2736922540001, 10.042181708000143], [98.27515709700012, 10.035834052000112], [98.28101647200006, 10.028387762000136], [98.2893986340001, 10.024318752000084], [98.29411868600013, 10.019110419000171], [98.28825931100008, 10.007961330000157], [98.26921634200006, 10.002590236000103], [98.25814863400014, 9.985988674000138], [98.25123131600006, 9.968329169000128], [98.24390709700006, 9.960109768000137], [98.22779381600017, 9.954006252000141], [98.1935327480002, 9.931463934000163], [98.17896569100016, 9.932806708000143], [98.17546634200006, 9.921454169000171], [98.17090905000012, 9.912258205000114], [98.16846764400012, 9.90460846600017], [98.17156009200008, 9.898098049000081], [98.14576256600006, 9.85683828300013], [98.13347415500019, 9.845607815000136], [98.1311955090001, 9.864488023000163], [98.12061608200005, 9.86131419500019], [98.11719811300006, 9.8820254580001], [98.1181746750001, 9.90851471600017], [98.120371941, 9.922552802000126], [98.124278191, 9.93138255400008], [98.12745201900006, 9.960109768000137], [98.14063561300006, 9.963283596000096], [98.14820397200018, 9.970363674000154], [98.15186608200005, 9.977443752000127], [98.15447024800001, 9.980617580000086], [98.16016686300011, 9.98411692900008], [98.16431725400017, 9.992254950000103], [98.16781660200016, 10.001410223000079], [98.17156009200008, 10.007961330000157], [98.17896569100016, 10.01410553600013], [98.20573978000006, 10.028998114000089], [98.23462975400017, 10.05418528900016], [98.25440514400012, 10.062689520000092]]], [[[98.19532311300004, 10.07050202000009], [98.18580162900017, 10.042059637000165], [98.18580162900017, 10.121161200000158], [98.18360436300011, 10.127020575000103], [98.17383873800006, 10.140122789000173], [98.17156009200008, 10.148138739000116], [98.17530358200011, 10.159409898000106], [98.18189537900017, 10.168605861000088], [98.18523196700019, 10.176825262000179], [98.17896569100016, 10.185451565000093], [98.17896569100016, 10.192857164000158], [98.196055535, 10.193182684000092], [98.22217858200005, 10.17792389500012], [98.2404891290001, 10.172349351000122], [98.24089603000002, 10.167792059000163], [98.23951256600004, 10.16648997600008], [98.23682701900006, 10.166408596000096], [98.23365319099999, 10.165513414000188], [98.23072350400017, 10.159572658000073], [98.22779381600017, 10.155259507000082], [98.22771243600019, 10.150824286000102], [98.23365319099999, 10.14447663000007], [98.21843509200002, 10.136175848000093], [98.2077742850001, 10.128648179000123], [98.20142662900015, 10.118068752000083], [98.19532311300004, 10.07050202000009]]], [[[97.90870201900012, 10.47345612200013], [97.91944420700011, 10.473089911000116], [97.925059441, 10.474066473000093], [97.93067467500012, 10.468166408000158], [97.93531334700006, 10.461167710000083], [97.94353274800002, 10.443793036000102 ...
# {'properties': {'code': 'UA', 'Year': 2013, 'income_grp': '4. Lower middle income', 'color': '#98FB98', 'TraffickingStats': {'RU': 174.0, 'Total': 638.0, 'UA': 464.0}, 'economy': '6. Developing region', 'sovereignt': 'Ukraine', 'type': 'Sovereign country', 'arrowPath': ['RU', [40.15954309100018, 49.333579000000114], [132.39966881600017, 42.852118231000034], 174.0], 'name': 'Ukraine', 'GDP(ppp)': 393000000000.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e49d'), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[29.807465040000153, 45.614325262000094], [29.73096764400017, 45.59137604400011], [29.78126061300023, 45.61066315300015], [29.801442905000073, 45.621893622000144], [29.809418165000093, 45.63165924700009], [29.81478925900015, 45.641058661000116], [29.82764733200011, 45.64472077000006], [29.8431095710001, 45.64618561400012], [29.856700066000172, 45.649115302000055], [29.872731967000078, 45.65827057500003], [29.901621941000176, 45.68048737200009], [29.918711785000113, 45.69065989800013], [30.07569420700011, 45.79242584800009], [30.125987175000066, 45.81146881700009], [29.908050977000098, 45.666449286000145], [29.807465040000153, 45.614325262000094]]], [[[32.63933353000018, 46.060003973000065], [32.783213738000114, 46.04633209800012], [32.852061394000174, 46.056301174], [32.88168379000009, 46.05540599200013], [32.913584832000225, 46.03880442900007], [32.954844597000175, 46.05174388200008], [32.97868899800008, 46.05329010600012], [32.98926842500012, 46.04262929900007], [32.9993595710001, 46.03530508000007], [33.045095248000194, 46.03790924700017], [33.05746504000015, 46.02521393400012], [33.04004967500006, 46.012152411000116], [32.61939537900011, 46.060003973000065], [32.62671959700012, 46.06590403900019], [32.63135826900023, 46.066229559000114], [32.63933353000018, 46.060003973000065]]], [[[32.153086785000106, 46.155991929000045], [32.16627037900017, 46.14935944200009], [32.143890821000156, 46.15265534100002], [32.10181725400011, 46.166693427000084], [31.737152540000096, 46.220770575000145], [31.580332879000167, 46.26276276200004], [31.549001498000134, 46.282416083], [31.521983269000057, 46.31321849200007], [31.514008009000094, 46.32941315300011], [31.50505618600019, 46.354925848], [31.50440514400023, 46.37335846600014], [31.521983269000057, 46.36847565300017], [31.538422071000156, 46.325832424000126], [31.554372592000192, 46.296332098000065], [31.5779728520001, 46.27558014500006], [31.618174675000116, 46.259222723000065], [31.940277540000093, 46.2045759140001], [32.070811394000174, 46.18244049700003], [32.153086785000106, 46.155991929000045]]], [[[33.19650557500009, 52.36894928000005], [33.29432906100007, 52.357296245], [33.35897627700009, 52.35755462700014], [33.3761845290002, 52.355255025000034], [33.400576080000036, 52.34434301700009], [33.40367639200005, 52.342956035], [33.41933435100023, 52.33833099400012], [33.43731774900012, 52.33915781700016], [33.45178715000023, 52.34525563600012], [33.46532637600009, 52.35274871800006], [33.48051924600023, 52.35776133300011], [33.49943282100017, 52.34099233000016], [33.493024943000165, 52.30313934300007], [33.510078166000056, 52.28753306100013], [33.53167891500007, 52.288824972000086], [33.60020186400007, 52.33078623500007], [33.68794844500022, 52.355823466000075], [33.73357873600011, 52.360991109000096], [33.77895064300011, 52.360060934000145], [33.80406538900016, 52.35460907000005], [33.8152274980001, 52.345074768000146], [33.82339237500011, 52.331458029000075], [33.839102010000175, 52.3139138800001], [33.8587390540001, 52.30215749100002], [33.900700317000116, 52.28585357700017], [33.919510539000015, 52.269756369], [33.9444185790002, 52.23577911400015], [33.95775109900009, 52.22469451900015], [34.021933228000165, 52.197900289000174], [34.03888309700008, 52.186479798000065], [34.055729614000114, 52.170330913], [34.065341431000064, 52.15862620100002], [34.07102583800011, 52.14896270800007], [34.07360966000007, 52.139557597000035], [34.07391971900009, 52.12831797 ...
# {'properties': {'code': 'UZ', 'Year': 2013, 'income_grp': '4. Lower middle income', 'color': '#F0E68C', 'TraffickingStats': {'Total': 115.0, 'UZ': 115.0}, 'economy': '6. Developing region', 'sovereignt': 'Uzbekistan', 'type': 'Sovereign country', 'arrowPath': [], 'name': 'Uzbekistan', 'GDP(ppp)': 159000000000.0}, 'type': 'Feature', '_id': ObjectId('5c377de4fd75f4171249e4b1'), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[71.75730432100013, 39.9030951940001], [71.74180139100011, 39.900769755000155], [71.71616988100007, 39.9067642210001], [71.6968428960001, 39.913843892000116], [71.67534550000008, 39.92578114900006], [71.66552697800009, 39.940198873000085], [71.6817533780002, 39.95508168600013], [71.70686812300019, 39.95611521400009], [71.72412805200011, 39.96267812100008], [71.76061161300012, 39.983710429], [71.78551965400018, 39.989704895000116], [71.78975712100012, 39.979317932000114], [71.76712284300018, 39.915445862000134], [71.75730432100013, 39.9030951940001]]], [[[71.16938155100014, 40.04282826700016], [71.17692631000014, 40.04200144500014], [71.1818872480001, 40.04339670800012], [71.19294600500008, 40.05026967400009], [71.198217, 40.052595113], [71.22374515800006, 40.057866109000045], [71.23635420800005, 40.05605743400015], [71.24400231900003, 40.046755677000036], [71.23728438300012, 40.03109771700015], [71.19098230000006, 40.00624135400004], [71.17470422400012, 39.993994039000185], [71.17702966300007, 39.968155823000174], [71.22105798400011, 39.931723938000076], [71.21909427900019, 39.90092478500009], [71.20844893400007, 39.888780823], [71.19459965000013, 39.88480173800012], [71.1610099690001, 39.88423329700008], [71.11367435700006, 39.87446645200011], [71.09889489800011, 39.875499980000185], [71.08721602400007, 39.883819886000154], [71.08478723100008, 39.89482696600005], [71.07998132300006, 39.90340525400008], [71.060964396, 39.904128723000085], [71.04980228700018, 39.89797922800001], [71.03605635600016, 39.88754058900015], [71.02189701400019, 39.880822652000134], [71.0092879640001, 39.88573191300015], [71.00763431800013, 39.911156718000186], [71.05037072800022, 39.96288482700014], [71.0458232010001, 39.99203033500005], [71.0342993570001, 39.99911000600018], [71.00763431800013, 40.003502503000064], [70.99450850400015, 40.00887685200003], [70.98313969000017, 40.021382548000034], [70.95843835400015, 40.06308542900016], [70.95296065300008, 40.07920847600006], [70.95404585800017, 40.09579661100007], [70.95988529400003, 40.11341827400004], [70.97714522300006, 40.14457916300002], [71.00856449400007, 40.15775665299999], [71.03119877200001, 40.146904603000124], [71.04794193500018, 40.12251332600003], [71.06173954200014, 40.095176493000096], [71.07884444200008, 40.07864003600018], [71.10597456900015, 40.06494578100016], [71.16204349800009, 40.04691070600016], [71.16545414200019, 40.04463694300016], [71.16938155100014, 40.04282826700016]]], [[[62.005961548000215, 43.486984965000076], [62.026115357000066, 43.480628765000134], [62.02832051600009, 43.48092238300008], [62.11091638200011, 43.491920065], [62.14605635600017, 43.4966742970001], [62.18140303500016, 43.50142852900008], [62.21674971600006, 43.50615692200007], [62.25188968900013, 43.51085947700015], [62.30842370600006, 43.51840423599999], [62.36485437000013, 43.52600067100015], [62.42128503400008, 43.53359710700011], [62.47771569800008, 43.54111602900014], [62.56897627800018, 43.55189056400008], [62.660236857000065, 43.56271677600013], [62.7514974370001, 43.573491313000076], [62.84286136900019, 43.58429168800011], [62.934121949000115, 43.595066223000046], [63.02538252800011, 43.60584076000005], [63.1166431070001, 43.61661529600018], [63.208007040000126, 43.62746734700012], [63.36034916200012, 43.617416281000104], [63.512691284000105, 43.60726186100013], [63.66513676000014, 43.597288310000025], [63.81737552900008, 43.587237244], [63.95592004400012, 43.578064678000096], [64.09467126500013, 43.568917949000124], [64.23316410300006, 43.55971954400003], [64.37165694200 ...
