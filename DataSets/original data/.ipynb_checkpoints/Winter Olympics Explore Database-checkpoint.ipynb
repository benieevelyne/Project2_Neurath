# %%
import pandas as pd
import numpy as np

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, distinct

from flask import(
    Flask,
    render_template,
    jsonify
)

# %%
# Database Setup
engine = create_engine("sqlite:///db/winter_olympics.sqlite")

# reflect existing database into new model
Base = automap_base()

# reflect tables
Base.prepare(engine, reflect=True)

# save reference to tables
medals = Base.classes.medals

# create session to query tables
session = Session(engine)

# create inspector to get column names
inspector = inspect(engine)

# %%
#set filters
gender = 'Women'
medal_type = 'gold'

# %%
# get medal info

#filter by medal type and gender
if gender!='both' and medal_type!='all':
    number_of_events_with_medal_wins = session.query(medals.year,medals.country,func.count(distinct(medals.sport))).filter(medals.gender==gender).filter(medals.medal==medal_type).group_by(medals.year).group_by(medals.country).all() 
    number_of_medal_wins = session.query(medals.year,medals.country,func.count(medals.sport)).group_by(medals.year).filter(medals.gender==gender).filter(medals.medal==medal_type).group_by(medals.country).all()

#just filter by type of medal
elif gender=='both' and medal_type!='all':
    number_of_events_with_medal_wins = session.query(medals.year,medals.country,func.count(distinct(medals.sport))).filter(medals.medal==medal_type).group_by(medals.year).group_by(medals.country).all() 
    number_of_medal_wins = session.query(medals.year,medals.country,func.count(medals.sport)).group_by(medals.year).filter(medals.medal==medal_type).group_by(medals.country).all()

#just filter by gender
elif gender!='both' and medal_type=='all':
    number_of_events_with_medal_wins = session.query(medals.year,medals.country,func.count(distinct(medals.sport))).filter(medals.gender==gender).group_by(medals.year).group_by(medals.country).all() 
    number_of_medal_wins = session.query(medals.year,medals.country,func.count(medals.sport)).group_by(medals.year).filter(medals.gender==gender).group_by(medals.country).all() 

#no filter
else:
    number_of_events_with_medal_wins = session.query(medals.year,medals.country,func.count(distinct(medals.sport))).group_by(medals.year).group_by(medals.country).all() 
    number_of_medal_wins = session.query(medals.year,medals.country,func.count(medals.sport)).group_by(medals.year).group_by(medals.country).all()

# %%
number_of_events_with_medal_wins
# Out:
# [(1924, 'Austria', 1),
#  (1928, 'Norway', 1),
#  (1932, 'Norway', 1),
#  (1936, 'Germany', 1),
#  (1936, 'Norway', 1),
#  (1948, 'Austria', 1),
#  (1948, 'Canada', 1),
#  (1948, 'Switzerland', 1),
#  (1948, 'United States', 1),
#  (1952, 'Austria', 1),
#  (1952, 'Britain', 1),
#  (1952, 'Finland', 1),
#  (1952, 'United States', 1),
#  (1956, 'Finland', 1),
#  (1956, 'Germany', 1),
#  (1956, 'Soviet Union', 1),
#  (1956, 'Switzerland', 1),
#  (1956, 'United States', 1),
#  (1960, 'Canada', 1),
#  (1960, 'Germany', 2),
#  (1960, 'Soviet Union', 2),
#  (1960, 'Sweden', 1),
#  (1960, 'Switzerland', 1),
#  (1960, 'United States', 1),
#  (1964, 'Austria', 1),
#  (1964, 'France', 1),
#  (1964, 'Germany', 1),
#  (1964, 'Netherlands', 1),
#  (1964, 'Soviet Union', 2),
#  (1968, 'Austria', 1),
#  (1968, 'Canada', 1),
#  (1968, 'Finland', 1),
#  (1968, 'France', 1),
#  (1968, 'Italy', 1),
#  (1968, 'Netherlands', 1),
#  (1968, 'Norway', 1),
#  (1968, 'Soviet Union', 1),
#  (1968, 'Sweden', 1),
#  (1968, 'United States', 1),
#  (1972, 'Austria', 1),
#  (1972, 'East Germany', 1),
#  (1972, 'Netherlands', 1),
#  (1972, 'Soviet Union', 1),
#  (1972, 'Switzerland', 1),
#  (1972, 'United States', 2),
#  (1972, 'West Germany', 1),
#  (1976, 'Canada', 1),
#  (1976, 'East Germany', 1),
#  (1976, 'Finland', 1),
#  (1976, 'Soviet Union', 2),
#  (1976, 'United States', 2),
#  (1976, 'West Germany', 1),
#  (1980, 'Austria', 1),
#  (1980, 'East Germany', 3),
#  (1980, 'Liechtenstein', 1),
#  (1980, 'Netherlands', 1),
#  (1980, 'Norway', 1),
#  (1980, 'Soviet Union', 3),
#  (1984, 'East Germany', 3),
#  (1984, 'Finland', 1),
#  (1984, 'Italy', 1),
#  (1984, 'Norway', 1),
#  (1984, 'Switzerland', 1),
#  (1984, 'United States', 1),
#  (1988, 'Austria', 1),
#  (1988, 'East Germany', 3),
#  (1988, 'Finland', 1),
#  (1988, 'Netherlands', 1),
#  (1988, 'Soviet Union', 1),
#  (1988, 'Switzerland', 1),
#  (1988, 'United States', 1),
#  (1988, 'West Germany', 1),
#  (1992, 'Austria', 2),
#  (1992, 'Canada', 2),
#  (1992, 'Finland', 1),
#  (1992, 'France', 1),
#  (1992, 'Germany', 2),
#  (1992, 'Italy', 2),
#  (1992, 'Sweden', 1),
#  (1992, 'Unified Team', 2),
#  (1992, 'United States', 4),
#  (1994, 'Austria', 1),
#  (1994, 'Canada', 1),
#  (1994, 'Germany', 2),
#  (1994, 'Italy', 3),
#  (1994, 'Norway', 1),
#  (1994, 'Russia', 3),
#  (1994, 'South Korea', 1),
#  (1994, 'Sweden', 1),
#  (1994, 'Switzerland', 1),
#  (1994, 'Ukraine', 1),
#  (1994, 'United States', 3),
#  (1994, 'Uzbekistan', 1),
#  (1998, 'Bulgaria', 1),
#  (1998, 'Canada', 3),
#  (1998, 'France', 1),
#  (1998, 'Germany', 5),
#  (1998, 'Italy', 1),
#  (1998, 'Japan', 1),
#  (1998, 'Netherlands', 1),
#  (1998, 'Russia', 2),
#  (1998, 'South Korea', 1),
#  (1998, 'United States', 4),
#  (2002, 'Australia', 1),
#  (2002, 'Britain', 1),
#  (2002, 'Canada', 3),
#  (2002, 'China', 1),
#  (2002, 'Croatia', 1),
#  (2002, 'France', 2),
#  (2002, 'Germany', 4),
#  (2002, 'Italy', 2),
#  (2002, 'Norway', 2),
#  (2002, 'Russia', 2),
#  (2002, 'South Korea', 1),
#  (2002, 'United States', 5),
#  (2006, 'Austria', 1),
#  (2006, 'Canada', 4),
#  (2006, 'China', 1),
#  (2006, 'Croatia', 1),
#  (2006, 'Czech Republic', 1),
#  (2006, 'Estonia', 1),
#  (2006, 'France', 1),
#  (2006, 'Germany', 4),
#  (2006, 'Japan', 1),
#  (2006, 'Netherlands', 1),
#  (2006, 'Russia', 3),
#  (2006, 'South Korea', 1),
#  (2006, 'Sweden', 4),
#  (2006, 'Switzerland', 3),
#  (2006, 'United States', 2),
#  (2010, 'Australia', 2),
#  (2010, 'Austria', 1),
#  (2010, 'Britain', 1),
#  (2010, 'Canada', 5),
#  (2010, 'China', 1),
#  (2010, 'Czech Republic', 1),
#  (2010, 'Germany', 5),
#  (2010, 'Netherlands', 2),
#  (2010, 'Norway', 2),
#  (2010, 'Poland', 1),
#  (2010, 'Russia', 1),
#  (2010, 'Slovakia', 1),
#  (2010, 'South Korea', 2),
#  (2010, 'Sweden', 2),
#  (2010, 'United States', 2),
#  (2014, 'Austria', 2),
#  (2014, 'Belarus', 2),
#  (2014, 'Britain', 1),
#  (2014, 'Canada', 4),
#  (2014, 'China', 2),
#  (2014, 'Czech Republic', 2),
#  (2014, 'Germany', 3),
#  (2014, 'Netherlands', 1),
#  (2014, 'Norway', 1),
#  (2014, 'Poland', 1),
#  (2014, 'Russia', 1),
#  (2014, 'Slovakia', 1),
#  (2014, 'Slovenia', 1),
#  (2014, 'South Korea', 2),
#  (2014, 'Sweden', 1),
#  (2014, 'Switzerland', 2),
#  (2014, 'Ukraine', 1),
#  (2014, 'United States', 3)]

# %%
number_of_medal_wins
# Out:
# [(1924, 'Austria', 1),
#  (1928, 'Norway', 1),
#  (1932, 'Norway', 1),
#  (1936, 'Germany', 1),
#  (1936, 'Norway', 1),
#  (1948, 'Austria', 1),
#  (1948, 'Canada', 1),
#  (1948, 'Switzerland', 1),
#  (1948, 'United States', 1),
#  (1952, 'Austria', 1),
#  (1952, 'Britain', 1),
#  (1952, 'Finland', 1),
#  (1952, 'United States', 2),
#  (1956, 'Finland', 1),
#  (1956, 'Germany', 1),
#  (1956, 'Soviet Union', 1),
#  (1956, 'Switzerland', 2),
#  (1956, 'United States', 1),
#  (1960, 'Canada', 1),
#  (1960, 'Germany', 2),
#  (1960, 'Soviet Union', 4),
#  (1960, 'Sweden', 1),
#  (1960, 'Switzerland', 1),
#  (1960, 'United States', 1),
#  (1964, 'Austria', 1),
#  (1964, 'France', 2),
#  (1964, 'Germany', 1),
#  (1964, 'Netherlands', 1),
#  (1964, 'Soviet Union', 7),
#  (1968, 'Austria', 1),
#  (1968, 'Canada', 1),
#  (1968, 'Finland', 1),
#  (1968, 'France', 1),
#  (1968, 'Italy', 1),
#  (1968, 'Netherlands', 2),
#  (1968, 'Norway', 1),
#  (1968, 'Soviet Union', 1),
#  (1968, 'Sweden', 2),
#  (1968, 'United States', 1),
#  (1972, 'Austria', 1),
#  (1972, 'East Germany', 1),
#  (1972, 'Netherlands', 1),
#  (1972, 'Soviet Union', 3),
#  (1972, 'Switzerland', 2),
#  (1972, 'United States', 3),
#  (1972, 'West Germany', 1),
#  (1976, 'Canada', 1),
#  (1976, 'East Germany', 1),
#  (1976, 'Finland', 1),
#  (1976, 'Soviet Union', 5),
#  (1976, 'United States', 2),
#  (1976, 'West Germany', 2),
#  (1980, 'Austria', 1),
#  (1980, 'East Germany', 4),
#  (1980, 'Liechtenstein', 2),
#  (1980, 'Netherlands', 1),
#  (1980, 'Norway', 1),
#  (1980, 'Soviet Union', 3),
#  (1984, 'East Germany', 6),
#  (1984, 'Finland', 3),
#  (1984, 'Italy', 1),
#  (1984, 'Norway', 1),
#  (1984, 'Switzerland', 1),
#  (1984, 'United States', 1),
#  (1988, 'Austria', 2),
#  (1988, 'East Germany', 3),
#  (1988, 'Finland', 1),
#  (1988, 'Netherlands', 3),
#  (1988, 'Soviet Union', 3),
#  (1988, 'Switzerland', 2),
#  (1988, 'United States', 1),
#  (1988, 'West Germany', 1),
#  (1992, 'Austria', 3),
#  (1992, 'Canada', 2),
#  (1992, 'Finland', 1),
#  (1992, 'France', 1),
#  (1992, 'Germany', 4),
#  (1992, 'Italy', 2),
#  (1992, 'Sweden', 1),
#  (1992, 'Unified Team', 4),
#  (1992, 'United States', 5),
#  (1994, 'Austria', 1),
#  (1994, 'Canada', 2),
#  (1994, 'Germany', 2),
#  (1994, 'Italy', 4),
#  (1994, 'Norway', 1),
#  (1994, 'Russia', 5),
#  (1994, 'South Korea', 2),
#  (1994, 'Sweden', 1),
#  (1994, 'Switzerland', 1),
#  (1994, 'Ukraine', 1),
#  (1994, 'United States', 4),
#  (1994, 'Uzbekistan', 1),
#  (1998, 'Bulgaria', 1),
#  (1998, 'Canada', 3),
#  (1998, 'France', 1),
#  (1998, 'Germany', 8),
#  (1998, 'Italy', 1),
#  (1998, 'Japan', 1),
#  (1998, 'Netherlands', 2),
#  (1998, 'Russia', 6),
#  (1998, 'South Korea', 2),
#  (1998, 'United States', 4),
#  (2002, 'Australia', 1),
#  (2002, 'Britain', 1),
#  (2002, 'Canada', 3),
#  (2002, 'China', 2),
#  (2002, 'Croatia', 3),
#  (2002, 'France', 2),
#  (2002, 'Germany', 8),
#  (2002, 'Italy', 3),
#  (2002, 'Norway', 2),
#  (2002, 'Russia', 2),
#  (2002, 'South Korea', 2),
#  (2002, 'United States', 5),
#  (2006, 'Austria', 2),
#  (2006, 'Canada', 5),
#  (2006, 'China', 1),
#  (2006, 'Croatia', 1),
#  (2006, 'Czech Republic', 1),
#  (2006, 'Estonia', 2),
#  (2006, 'France', 1),
#  (2006, 'Germany', 4),
#  (2006, 'Japan', 1),
#  (2006, 'Netherlands', 2),
#  (2006, 'Russia', 4),
#  (2006, 'South Korea', 3),
#  (2006, 'Sweden', 4),
#  (2006, 'Switzerland', 4),
#  (2006, 'United States', 2),
#  (2010, 'Australia', 2),
#  (2010, 'Austria', 1),
#  (2010, 'Britain', 1),
#  (2010, 'Canada', 5),
#  (2010, 'China', 4),
#  (2010, 'Czech Republic', 2),
#  (2010, 'Germany', 8),
#  (2010, 'Netherlands', 2),
#  (2010, 'Norway', 4),
#  (2010, 'Poland', 1),
#  (2010, 'Russia', 1),
#  (2010, 'Slovakia', 1),
#  (2010, 'South Korea', 2),
#  (2010, 'Sweden', 2),
#  (2010, 'United States', 2),
#  (2014, 'Austria', 2),
#  (2014, 'Belarus', 4),
#  (2014, 'Britain', 1),
#  (2014, 'Canada', 6),
#  (2014, 'China', 3),
#  (2014, 'Czech Republic', 2),
#  (2014, 'Germany', 3),
#  (2014, 'Netherlands', 3),
#  (2014, 'Norway', 4),
#  (2014, 'Poland', 1),
#  (2014, 'Russia', 1),
#  (2014, 'Slovakia', 1),
#  (2014, 'Slovenia', 2),
#  (2014, 'South Korea', 3),
#  (2014, 'Sweden', 1),
#  (2014, 'Switzerland', 2),
#  (2014, 'Ukraine', 1),
#  (2014, 'United States', 4)]

# %%
genders = session.query(distinct(medals.gender)).all()
genders
# Out:
# [('Men'), ('Mixed'), ('Women')]
